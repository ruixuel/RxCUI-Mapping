# %%
import pandas as pd

# %%
RxCUI_file = pd.read_csv("../../rxcui/RxCUI.csv")

# %%
missingRxCUI = pd.isnull(RxCUI_file.RxCUI)
queries_missing = RxCUI_file.ix[missingRxCUI].Query
#Extract unique values
queries_missing = set(queries_missing)

# %%
len(queries_missing)
# Out:
# 4409

# %%
1-float(sum(missingRxCUI))/len(RxCUI_file.index)
# Out:
# 12920

# %%
queries_missing
# Out:
# {'OXYBUTYNIN CHLORIDE 100MG/PACKET GEL TRANSDERMAL',
#  'ESTROGENS CONJUGATED SYNTHETIC A 0.3MG TABLET ORAL',
#  'GLYCOPYRROLATE 5.6 POWDER INHALATION',
#  'AZTREONAM 500MG INJECTABLE INJECTION',
#  'ATROPINE  PRALIDOXIME CHLORIDE 2.1MG 0.7ML 600MG 2ML INJECTABLE INTRAMUSCULAR',
#  'SAFFLOWER OIL  SOYBEAN OIL 5GM/100ML INJECTABLE INJECTION',
#  'PIPERACILLIN SODIUM  TAZOBACTAM SODIUM 36GM 4.5GM INJECTABLE INJECTION',
#  'ESTRADIOL 1GM/PACKET GEL TRANSDERMAL',
#  'PREDNISOLONE SODIUM PHOSPHATE  SULFACETAMIDE SODIUM 0.2 3% 10% SOLUTION/DROPS OPHTHALMIC',
#  'ERYTHROMYCIN 0.5 0% OINTMENT OPHTHALMIC',
#  'AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE  VALSARTAN 5MG 2.5MG 160MG TABLET ORAL',
#  'DAPTOMYCIN 500MG POWDER INTRAVENOUS',
#  'ESTRADIOL 0.06MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'RANITIDINE HYDROCHLORIDE 1MG INJECTABLE INJECTION',
#  'OCTREOTIDE ACETATE 30MG INJECTABLE INJECTION',
#  'TIOTROPIUM BROMIDE 0.0025MG SPRAY METERED INHALATION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.3MG 100ML 2.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'FENTANYL CITRATE 0.8MG TABLET BUCCAL SUBLINGUAL',
#  'SODIUM MONOFLUOROPHOSPHATE 1.2 0% PASTE DENTAL',
#  'ALCOHOL  DEXTROSE 10ML 100ML 5GM 100ML INJECTABLE INJECTION',
#  'FONDAPARINUX SODIUM 2.5MG 0.5ML INJECTABLE SUBCUTANEOUS',
#  'PHENYL AMINOSALICYLATE 50% POWDER ORAL',
#  'SULFUR HEXAFLUORIDE LIPID-TYPE A MICROSPHERES 0.7MG 25MG FOR SUSPENSION INTRAVENOUS',
#  'MIVACURIUM CHLORIDE 50MG 100ML INJECTABLE INJECTION',
#  'IPRATROPIUM BROMIDE 0.0 2% SOLUTION INHALATION',
#  'HETACILLIN 112 5MG FOR SUSPENSION ORAL',
#  'GENTAMICIN SULFATE 90MG 100ML INJECTABLE INJECTION',
#  'INSULIN ZINC SUSP PURIFIED PORK 100 INJECTABLE INJECTION',
#  'CEFTIZOXIME SODIUM 40MG INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE 20MEQ **Federal Register determination that product was not discontinued or withdrawn for safety or efficacy reasons** TABLET EXTENDED RELEASE ORAL',
#  'DOXYLAMINE SUCCINATE 2.5MG TABLET ORAL',
#  'CLOFARABINE 1MG/ML INJECTABLE IV INFUSION',
#  'DROSPIRENONE  ETHINYL ESTRADIOL 3MG 0.03MG TABLET ORAL-28',
#  'MYCOPHENOLATE MOFETIL HYDROCHLORIDE 500MG INJECTABLE INJECTION',
#  'METHYLTESTOSTERONE 10MG TABLET BUCCAL',
#  'NANDROLONE DECANOATE 200MG INJECTABLE INJECTION',
#  'BUDESONIDE  FORMOTEROL FUMARATE DIHYDRATE 0.16MG 0.0045MG AEROSOL METERED INHALATION',
#  'PENICILLIN G POTASSIUM 00 TABLET ORAL',
#  'HEPARIN SODIUM 75 0.5ML INJECTABLE INJECTION',
#  'LIDOCAINE HYDROCHLORIDE 3.5 0% GEL OPHTHALMIC',
#  'HYDROCORTISONE 0.5 0% OINTMENT TOPICAL',
#  'AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE  OLMESARTAN MEDOXOMIL 5MG 2.5MG 20MG TABLET ORAL',
#  'CYTARABINE 2GM INJECTABLE INJECTION',
#  'CLIDINIUM BROMIDE 5MG CAPSULE ORAL',
#  'FUROSEMIDE 10MG SOLUTION ORAL',
#  'CIMETIDINE HYDROCHLORIDE 300MG 2ML INJECTABLE INJECTION',
#  'NITROFURANTOIN SODIUM 180MG INJECTABLE INJECTION',
#  'CHLORPROMAZINE HYDROCHLORIDE 200MG CAPSULE EXTENDED RELEASE ORAL',
#  'BACITRACIN ZINC 500 000 POWDER FOR RX COMPOUNDING',
#  'HYDROCHLOROTHIAZIDE  TRIAMTERENE 25MG 7.5MG CAPSULE ORAL',
#  'PHENTERMINE HYDROCHLORIDE 7.5MG TABLET ORAL',
#  'BUPRENORPHINE HYDROCHLORIDE  NALOXONE HYDROCHLORIDE 4MG 1MG FILM BUCCAL SUBLINGUAL',
#  'ACETIC ACID GLACIAL 250MG 100ML SOLUTION IRRIGATION URETHRAL',
#  'LACTULOSE 20GM FOR SOLUTION ORAL',
#  'HYALURONIDASE RECOMBINANT HUMAN 150 INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 1MG TABLET ORAL-21',
#  'STAVUDINE 5MG CAPSULE ORAL',
#  'POTASSIUM AMINOSALICYLATE 1GM TABLET ORAL',
#  'ERYTHROMYCIN GLUCEPTATE 500MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 1MG TABLET ORAL-28',
#  'CEPHALOTHIN SODIUM 10GM INJECTABLE INJECTION',
#  'FLUOCINOLONE ACETONIDE 0.2 0% CREAM TOPICAL',
#  'POTASSIUM CHLORIDE 9.8MG INJECTABLE INJECTION',
#  'AMPHOTERICIN B 50MG INJECTABLE LIPOSOMAL INJECTION',
#  'INSULIN SUSP PROTAMINE ZINC PURIFIED BEEF 100 INJECTABLE INJECTION',
#  'BISACODYL  POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE 5MG 210GM 0.74GM 2.86GM 5.6GM FOR SOLUTION TABLET DELAYED RELEASE ORAL',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.035MG 0.035MG 0.18MG 0.215MG 0.25MG TABLET ORAL',
#  'TECHNETIUM TC-99M SODIUM PERTECHNETATE GENERATOR 0.2 2-2 SOLUTION INJECTION ORAL',
#  'GONADORELIN HYDROCHLORIDE 0.2MG INJECTABLE INJECTION',
#  'DOXEPIN HYDROCHLORIDE 10MG CONCENTRATE ORAL',
#  'ERGOTAMINE TARTRATE 0.36MG AEROSOL METERED INHALATION',
#  'SPIRAPRIL HYDROCHLORIDE 24MG TABLET ORAL',
#  'MOMETASONE FUROATE 0.1 0% LOTION TOPICAL',
#  'ALFENTANIL HYDROCHLORIDE 0.5MG INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.232MG POWDER INHALATION',
#  'PAMIDRONATE DISODIUM 60MG INJECTABLE INJECTION',
#  'RUFINAMIDE 100MG TABLET ORAL',
#  'DEXTROSE 60GM 100ML INJECTABLE INJECTION',
#  'ESMOLOL HYDROCHLORIDE 10MG INJECTABLE INJECTION',
#  'SODIUM POLYSTYRENE SULFONATE 454GM POWDER ORAL RECTAL',
#  'CYANOCOBALAMIN 0.5MG SPRAY METERED NASAL',
#  'CEFONICID SODIUM 500MG INJECTABLE INJECTION',
#  'IMIGLUCERASE 400 INJECTABLE INJECTION',
#  "ASCORBIC ACID  BIOTIN  CYANOCOBALAMIN  DEXPANTHENOL  ERGOCALCIFEROL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE  VITAMIN A  VITAMIN E 100MG 0.06MG 0.005MG 15MG 0.4MG 40MG 4MG 3.6MG 3MG 1MG 10MG INJECTABLE INJECTION",
#  'DOCETAXEL 20MG/ML INJECTABLE INJECTION',
#  'COPPER 309MG INTRAUTERINE DEVICE INTRAUTERINE',
#  'MEPROBAMATE 400MG CAPSULE EXTENDED RELEASE ORAL',
#  'TEDUGLUTIDE RECOMBINANT 5MG POWDER SUBCUTANEOUS',
#  'POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM SULFATE ANHYDROUS 236GM 2.97GM 6.74GM 5.86GM 2.74GM FOR SOLUTION ORAL',
#  'SELENOMETHIONINE SE-75 5-5 INJECTABLE INJECTION',
#  'PHENYLEPHRINE HYDROCHLORIDE 10MG/ML SOLUTION IV INFUSION',
#  'LEVOMETHADYL ACETATE HYDROCHLORIDE 10MG CONCENTRATE ORAL',
#  'FLUOCINONIDE 0.0 5% CREAM TOPICAL',
#  'CLOZAPINE 150MG TABLET ORALLY DISINTEGRATING ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 10GM 100ML 37MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'CITRIC ACID  MAGNESIUM OXIDE  SODIUM PICOSULFATE 12GM 3.5GM 10MG FOR SOLUTION ORAL',
#  'CHLORPHENIRAMINE MALEATE  PHENYLPROPANOLAMINE HYDROCHLORIDE 12MG 75MG CAPSULE EXTENDED RELEASE ORAL',
#  'NAFCILLIN SODIUM 1.5GM INJECTABLE INJECTION',
#  'ISOPROTERENOL HYDROCHLORIDE 0.12MG AEROSOL METERED INHALATION',
#  'MAGNESIUM SULFATE  POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  POTASSIUM SULFATE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM SULFATE 1.6GM 3.13GM 7.5GM 210GM 0.74GM 2.86GM 5.6GM SOLUTION ORAL',
#  'TRIDIHEXETHYL CHLORIDE 10MG INJECTABLE INJECTION',
#  'CISPLATIN 10MG INJECTABLE INJECTION',
#  'IOPHENDYLATE 100% INJECTABLE INJECTION',
#  'ESTRADIOL 0.87GM/ACTIVATION GEL METERED TRANSDERMAL',
#  'CYCLACILLIN 250MG 5ML FOR SUSPENSION ORAL',
#  'DAUNORUBICIN HYDROCHLORIDE 5MG INJECTABLE INJECTION',
#  'IDARUBICIN HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'OCTREOTIDE ACETATE 20MG INJECTABLE INJECTION',
#  'DEXAMETHASONE SODIUM PHOSPHATE 0.1 SOLUTION/DROPS OTIC',
#  'AMPICILLIN/AMPICILLIN TRIHYDRATE 500MG CAPSULE ORAL',
#  'NALOXONE HYDROCHLORIDE 4MG SPRAY METERED NASAL',
#  'AMPRENAVIR 15MG SOLUTION ORAL',
#  'BACLOFEN 0.5MG INJECTABLE INTRATHECAL',
#  'NITROGLYCERIN 0.4 0% OINTMENT INTRA-ANAL',
#  'DIDANOSINE 250MG FOR SOLUTION ORAL',
#  'NITROGLYCERIN 10MG 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 2.7 5% 25GM 100ML 51MG 100ML 261MG 100ML 216MG 100ML 112MG 100ML INJECTABLE INJECTION',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 10 10 70 CAPSULE DELAYED RELEASE ORAL',
#  'IOHEXOL 8.8 0% SOLUTION INJECTION ORAL RECTAL',
#  'HYDROCHLOROTHIAZIDE  TELMISARTAN 2.5MG 40MG TABLET ORAL',
#  'BUPIVACAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 0.2 5% 0.0091MG INJECTABLE INJECTION',
#  'CISAPRIDE MONOHYDRATE 1MG SUSPENSION ORAL',
#  'KETOROLAC TROMETHAMINE 0.4 0% SOLUTION/DROPS OPHTHALMIC',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  OXIGLUTATIONE  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM PHOSPHATE 0.154MG 0.92MG 0.2MG 0.184MG 0.38MG 2.1MG 7.14MG 0.42MG SOLUTION IRRIGATION',
#  'LEVODOPA 100MG CAPSULE ORAL',
#  'CEFORANIDE 20GM INJECTABLE INJECTION',
#  'DESERPIDINE 0.1MG TABLET ORAL',
#  'ALCAFTADINE 0.2 5% SOLUTION/DROPS OPHTHALMIC',
#  'DIATRIZOATE SODIUM 50% INJECTABLE INJECTION',
#  'CEFTIZOXIME SODIUM 1GM INJECTABLE INJECTION',
#  'METFORMIN HYDROCHLORIDE  ROSIGLITAZONE MALEATE 1GM 2MG TABLET ORAL',
#  'MEROPENEM 500MG INJECTABLE INJECTION',
#  'SODIUM IODIDE I-131 3.5 150 SOLUTION ORAL',
#  'BECLOMETHASONE DIPROPIONATE 0.042MG AEROSOL METERED INHALATION',
#  'ERGOLOID MESYLATES 0.5MG TABLET ORAL',
#  'NALBUPHINE HYDROCHLORIDE 1.5MG INJECTABLE INJECTION',
#  'COLESEVELAM HYDROCHLORIDE 1.875GM FOR SUSPENSION ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 1MG TABLET ORAL-21',
#  'AMMONIUM CHLORIDE 3MEQ/ML INJECTABLE INJECTION',
#  'NYSTATIN  TRIAMCINOLONE ACETONIDE 100 000 0.1 OINTMENT TOPICAL',
#  'IODOHIPPURATE SODIUM I-131 0.2 INJECTABLE INJECTION',
#  'DIAZOXIDE 15MG INJECTABLE INJECTION',
#  'CIMETIDINE HYDROCHLORIDE 120MG 100ML INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 1MG TABLET ORAL-28',
#  'DEXTROSE  POTASSIUM CHLORIDE 5GM 100ML 75MG 100ML INJECTABLE INJECTION',
#  'METHARBITAL 100MG TABLET ORAL',
#  'HYDROFLUMETHIAZIDE  RESERPINE 50MG 0.125MG TABLET ORAL',
#  'AVOBENZONE  ECAMSULE  OCTOCRYLENE  TITANIUM DIOXIDE 2% 3% 10% 5% CREAM TOPICAL',
#  'CLOBETASOL PROPIONATE 0.0 5% SHAMPOO TOPICAL',
#  'ROTIGOTINE 2MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'ESTRADIOL CYPIONATE  TESTOSTERONE CYPIONATE 2MG 50MG INJECTABLE INJECTION',
#  'RIVASTIGMINE 9.5MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'EMPAGLIFLOZIN  METFORMIN HYDROCHLORIDE 25MG 1GM TABLET EXTENDED RELEASE ORAL',
#  'EXENATIDE SYNTHETIC 250MCG/ML INJECTABLE SUBCUTANEOUS',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.035MG 0.035MG 0.18MG 0.215MG 0.25MG TABLET ORAL-21',
#  'HISTAMINE PHOSPHATE 0.1MG INJECTABLE INJECTION',
#  'AMIKACIN SULFATE 50MG INJECTABLE INJECTION',
#  'BROMODIPHENHYDRAMINE HYDROCHLORIDE  CODEINE PHOSPHATE 2.5MG 5ML 10MG 5ML SYRUP ORAL',
#  'FOSINOPRIL SODIUM  HYDROCHLOROTHIAZIDE 10MG 2.5MG TABLET ORAL',
#  'CARISOPRODOL 250MG CAPSULE ORAL',
#  'MORPHINE SULFATE 1MG INJECTABLE INJECTION',
#  'DORIPENEM 500MG INJECTABLE IV INFUSION',
#  'METHYLPHENIDATE 1.6MG/HR FILM EXTENDED RELEASE TRANSDERMAL',
#  'PROTOKYLOL HYDROCHLORIDE 2MG TABLET ORAL',
#  'METHDILAZINE HYDROCHLORIDE 4MG 5ML SYRUP ORAL',
#  'ACETAMINOPHEN  OXYCODONE HYDROCHLORIDE 325MG 5MG CAPSULE ORAL',
#  'DIHYDROERGOTAMINE MESYLATE  HEPARIN SODIUM  LIDOCAINE HYDROCHLORIDE 0.5MG 0.7ML 50 0.7ML 7.46MG 0.7ML INJECTABLE INJECTION',
#  'DIPHENHYDRAMINE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'ETHIODIZED OIL EQ 480MG IODINE/ML OIL INTRALYMPHATIC INTRAUTERINE',
#  'TRIPLE SULFA SULFABENZAMIDE SULFACETAMIDE SULFATHIAZOLE 3.7 2.8 6% 3.4 2% CREAM VAGINAL',
#  'CARBENICILLIN DISODIUM 1GM INJECTABLE INJECTION',
#  'AMINOSALICYLATE SODIUM 100% POWDER ORAL',
#  'HEPARIN SODIUM 40 100ML INJECTABLE INJECTION',
#  'DESIPRAMINE HYDROCHLORIDE 25MG CAPSULE ORAL',
#  'FLUOCINOLONE ACETONIDE 0.0 3% OINTMENT TOPICAL',
#  'LIDOCAINE 100MG SUPPOSITORY RECTAL',
#  'OFLOXACIN 40MG INJECTABLE INJECTION',
#  'FLUOCINOLONE ACETONIDE  NEOMYCIN SULFATE 0.0 25% 3.5MG CREAM TOPICAL',
#  'GANCICLOVIR  2MG/ML SOLUTION IV INFUSION',
#  'FLUORESCEIN SODIUM EQ 100MG BASE/ML INJECTABLE INTRAVENOUS',
#  'BENZOYL PEROXIDE  CLINDAMYCIN PHOSPHATE 3.7 5% 1.2 GEL TOPICAL',
#  'PROMAZINE HYDROCHLORIDE 200MG TABLET ORAL',
#  'OXACILLIN SODIUM 2GM POWDER INTRAVENOUS',
#  'FLUOCINOLONE ACETONIDE 0.0 1% OIL TOPICAL',
#  'CALCIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE 20MG 100ML 30MG 100ML 380MG 100ML 600MG 100ML INJECTABLE INJECTION',
#  'DIDANOSINE 200MG TABLET CHEWABLE ORAL',
#  'GRISEOFULVIN ULTRAMICROCRYSTALLINE 165MG TABLET ORAL',
#  'LIDOCAINE HYDROCHLORIDE 800MG 100ML INJECTABLE INJECTION',
#  'MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM GLUCONATE 30MG 100ML 37MG 100ML 222MG 100ML 526MG 100ML 502MG 100ML SOLUTION IRRIGATION',
#  'IBUPROFEN LYSINE EQ 10MG BASE/ML INJECTABLE INTRAVENOUS',
#  'LINCOMYCIN HYDROCHLORIDE 300MG INJECTABLE INJECTION',
#  'DAUNORUBICIN CITRATE 2MG INJECTABLE LIPOSOMAL INJECTION',
#  'PROCHLORPERAZINE EDISYLATE 5MG INJECTABLE INJECTION',
#  'ZIDOVUDINE 200MG TABLET ORAL',
#  'PEGVISOMANT 25MG INJECTABLE SUBCUTANEOUS',
#  'MASOPROCOL 10% CREAM TOPICAL',
#  'MOXALACTAM DISODIUM 500MG INJECTABLE INJECTION',
#  'IBANDRONATE SODIUM 3MG 3ML INJECTABLE INTRAVENOUS',
#  'BETAMETHASONE DIPROPIONATE  CALCIPOTRIENE HYDRATE 0.0 64% 0.0 05% OINTMENT TOPICAL',
#  'FLORBETABEN F-18 1.4-135mCi/ML SOLUTION INTRAVENOUS',
#  'CLOBETASOL PROPIONATE 0.0 5% GEL TOPICAL',
#  'LEUCOVORIN CALCIUM 350MG INJECTABLE INJECTION',
#  'PHENYLEPHRINE HYDROCHLORIDE  PYRILAMINE MALEATE 0.1 2% 0.1 SOLUTION/DROPS OPHTHALMIC',
#  'DESOXYCORTICOSTERONE PIVALATE 25MG INJECTABLE INJECTION',
#  'TRISULFAPYRIMIDINES SULFADIAZINE SULFAMERAZINE SULFAMETHAZINE 167MG 5ML 167MG 5ML 167MG 5ML SUSPENSION ORAL',
#  'DIPYRIDAMOLE 5MG INJECTABLE INJECTION',
#  'SULFISOXAZOLE ACETYL 1GM 5ML EMULSION ORAL',
#  'MECASERMIN RECOMBINANT 10MG/ML INJECTABLE SUBCUTANEOUS',
#  'ENFUVIRTIDE 90MG INJECTABLE SUBCUTANEOUS',
#  'CIPROFLOXACIN 200MG 100ML INJECTABLE INJECTION',
#  'CEPHRADINE 4GM INJECTABLE INJECTION',
#  'CYSTEINE HYDROCHLORIDE 7.2 5% INJECTABLE INJECTION',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 20 50 10 CAPSULE DELAYED RELEASE ORAL',
#  'TACROLIMUS 0.0 3% OINTMENT TOPICAL',
#  'VERAPAMIL HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE 150MG 100ML 450MG 100ML INJECTABLE INJECTION',
#  'BACITRACIN ZINC  HYDROCORTISONE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 400 1% 3.5MG 50 OINTMENT TOPICAL',
#  'DOXAPRAM HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'CEFTAZIDIME SODIUM 20MG INJECTABLE INJECTION',
#  'METHYLDOPATE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'BENZTROPINE MESYLATE 1MG INJECTABLE INJECTION',
#  'PARAMETHADIONE 150MG CAPSULE ORAL',
#  'EFLORNITHINE HYDROCHLORIDE 200MG INJECTABLE INJECTION',
#  'CEFUROXIME SODIUM 30MG INJECTABLE INJECTION',
#  'NEOMYCIN SULFATE  POLYMYXIN B SULFATE 40MG 200 000 SOLUTION IRRIGATION',
#  'SODIUM PHOSPHATE P-32 1.5 SOLUTION INJECTION ORAL',
#  'DOXORUBICIN HYDROCHLORIDE 100MG INJECTABLE INJECTION',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE 120MG CAPSULE EXTENDED RELEASE ORAL',
#  'DIATRIZOATE SODIUM 40% SOLUTION ORAL RECTAL',
#  'STERILE WATER FOR INJECTION 100% LIQUID N/A',
#  'ZOLPIDEM TARTRATE 5MG TABLET ORALLY DISINTEGRATING ORAL',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.01MG 2% SOLUTION IONTOPHORESIS TOPICAL',
#  'HYALURONIDASE 150 INJECTABLE INJECTION',
#  'METHYLPREDNISOLONE ACETATE 40MG ENEMA RECTAL',
#  'ISOETHARINE HYDROCHLORIDE 0.0 6% SOLUTION INHALATION',
#  'TESTOSTERONE ENANTHATE 200MG INJECTABLE INJECTION',
#  'CYTARABINE 500MG INJECTABLE INJECTION',
#  "ASCORBIC ACID  BIOTIN  CYANOCOBALAMIN  DEXPANTHENOL  ERGOCALCIFEROL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE HYDROCHLORIDE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE HYDROCHLORIDE  VITAMIN A  VITAMIN E 20MG 0.006MG 0.0 1.5MG 0.0005MG 0.06MG 4MG 0.6MG 0.36MG 0.6MG 0.1MG 1MG INJECTABLE INJECTION",
#  'TICARCILLIN DISODIUM 6GM INJECTABLE INJECTION',
#  'AMLODIPINE BESYLATE 5MG TABLET ORALLY DISINTEGRATING ORAL',
#  'PRAMIPEXOLE DIHYDROCHLORIDE 1.25MG TABLET ORAL',
#  'ARTICAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 4% EQ 0.01MG BASE/ML INJECTABLE INJECTION',
#  'VINCRISTINE SULFATE 2MG INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  PROPRANOLOL HYDROCHLORIDE 50MG 160MG CAPSULE EXTENDED RELEASE ORAL',
#  'PENTETATE CALCIUM TRISODIUM EQ 200MG BASE/ML SOLUTION INHALATION INTRAVENOUS',
#  'TOPOTECAN HYDROCHLORIDE 4MG INJECTABLE INJECTION',
#  'DIATRIZOATE MEGLUMINE 76% INJECTABLE INJECTION',
#  'SPIRAPRIL HYDROCHLORIDE 12MG TABLET ORAL',
#  'ESTROPIPATE 6MG TABLET ORAL',
#  'LANSOPRAZOLE 30MG FOR SUSPENSION DELAYED RELEASE ORAL',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 4.2 5% 6.8MG 100ML 25GM 100ML 51MG 100ML 2.4MG 100ML 261MG 100ML 205MG 100ML INJECTABLE INJECTION',
#  'ESCITALOPRAM OXALATE 10MG CAPSULE ORAL',
#  'METHOCARBAMOL 100MG INJECTABLE INJECTION',
#  'RISPERIDONE 25MG INJECTABLE INTRAMUSCULAR',
#  'CALCIUM GLUCONATE 100MG/ML SOLUTION IV INFUSION',
#  'DYPHYLLINE 250MG INJECTABLE INJECTION',
#  'IODAMIDE MEGLUMINE 24% INJECTABLE INJECTION',
#  'CASPOFUNGIN ACETATE 50MG POWDER IV INFUSION',
#  'CLOFIBRATE 500MG CAPSULE ORAL',
#  'INSULIN ZINC SUSP EXTENDED RECOMBINANT HUMAN 100 INJECTABLE INJECTION',
#  'PENICILLIN V POTASSIUM 125MG TABLET ORAL',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 900MG 100ML INJECTABLE INJECTION',
#  'FLOXURIDINE 500MG INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 24MG INJECTABLE INJECTION',
#  'LEVOLEUCOVORIN CALCIUM EQ 10MG BASE/ML SOLUTION IV INFUSION',
#  'SOMATROPIN RECOMBINANT 2.5MG/ML INJECTABLE INJECTION',
#  'ALBUMIN IODINATED I-125 SERUM 500 0.5ML INJECTABLE INJECTION',
#  'MESTRANOL  NORETHYNODREL 0.075MG 5MG TABLET ORAL',
#  'CABOZANTINIB S-MALATE 20MG CAPSULE ORAL',
#  'LEUPROLIDE ACETATE  NORETHINDRONE ACETATE 3.75MG 5MG INJECTABLE TABLET INTRAMUSCULAR ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 10GM 100ML 75MG 100ML 450MG 100ML INJECTABLE INJECTION',
#  'FOSPROPOFOL DISODIUM 35MG/ML SOLUTION INTRAVENOUS',
#  'ERYTHROMYCIN ETHYLSUCCINATE  SULFISOXAZOLE ACETYL 200MG 5ML 600MG 5ML GRANULE ORAL',
#  'OXYTOCIN 100ML INJECTABLE INJECTION',
#  'FLUOROMETHOLONE 0.1 0% SUSPENSION/DROPS OPHTHALMIC',
#  'HEPARIN SODIUM 10 100ML INJECTABLE INJECTION',
#  'DIATRIZOATE SODIUM 100% FOR SOLUTION ORAL RECTAL',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE 149MG 100ML 450MG 100ML INJECTABLE INJECTION',
#  'IOFETAMINE HYDROCHLORIDE I-123 1mCi/ML INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE 6.7 TABLET EXTENDED RELEASE ORAL',
#  'AMINO ACIDS 10GM/100ML INJECTABLE INJECTION',
#  'METHYLTESTOSTERONE 5MG TABLET BUCCAL SUBLINGUAL',
#  'ERYTHROMYCIN 5MG OINTMENT OPHTHALMIC',
#  'PRAZOSIN HYDROCHLORIDE 2.5MG TABLET EXTENDED RELEASE ORAL',
#  'DEXAMETHASONE SODIUM PHOSPHATE  NEOMYCIN SULFATE 0.0 5% 3.5MG OINTMENT OPHTHALMIC',
#  'SULFISOXAZOLE DIOLAMINE 4% SOLUTION/DROPS OPHTHALMIC',
#  'ETHINYL ESTRADIOL  ETHYNODIOL DIACETATE 0.035MG 1MG TABLET ORAL-21',
#  'CHLORPHENIRAMINE MALEATE  IBUPROFEN  PSEUDOEPHEDRINE HYDROCHLORIDE 1MG 5ML 100MG 5ML 15MG 5ML SUSPENSION ORAL',
#  'DOPAMINE HYDROCHLORIDE 1.6MG INJECTABLE INJECTION',
#  'DOPAMINE HYDROCHLORIDE 40MG 100ML INJECTABLE INJECTION',
#  'FLUMAZENIL 0.1MG/ML INJECTABLE INJECTION',
#  'TESTOSTERONE 30MG TABLET EXTENDED RELEASE BUCCAL',
#  'PROGESTERONE 300MG CAPSULE ORAL',
#  'ASPIRIN  CAFFEINE  PROPOXYPHENE HYDROCHLORIDE 389MG 2.4MG 32MG CAPSULE ORAL',
#  'CHLORTHALIDONE  RESERPINE 50MG 0.25MG TABLET ORAL',
#  'PIPERAZINE CITRATE 500MG TABLET ORAL',
#  'SODIUM IODIDE I-131 250 100 SOLUTION ORAL',
#  'BACITRACIN ZINC  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 400 3.5MG 50 OINTMENT OPHTHALMIC',
#  'TECHNETIUM TC-99M MEDRONATE nan INJECTABLE INJECTION',
#  'TICARCILLIN DISODIUM 30GM INJECTABLE INJECTION',
#  'ARGATROBAN 1MG/ML SOLUTION IV INFUSION',
#  'LEUCOVORIN CALCIUM 50MG INJECTABLE INJECTION',
#  'MEPIVACAINE HYDROCHLORIDE 1.5 0% INJECTABLE INJECTION',
#  'THIOTEPA 100MG POWDER IV INFUSION',
#  'BUTABARBITAL SODIUM 100MG CAPSULE ORAL',
#  'PREDNISONE 5MG SOLUTION ORAL',
#  'ACETAMINOPHEN  ASPIRIN  CODEINE PHOSPHATE 150MG 180MG 15MG CAPSULE ORAL',
#  'CITRIC ACID  GLUCONOLACTONE  MAGNESIUM CARBONATE 6.602GM 100ML 198MG 100ML 3.177GM 100ML SOLUTION IRRIGATION',
#  'DALBAVANCIN HYDROCHLORIDE 500MG POWDER IV INFUSION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 0.035MG 0.035MG 0.5MG 1MG 0.5MG TABLET ORAL-28',
#  'DIENOGEST  ESTRADIOL VALERATE 2MG 3MG 3MG 2MG 2MG 1MG TABLET ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 3.3GM 100ML 150MG 100ML 300MG 100ML INJECTABLE INJECTION',
#  'MIVACURIUM CHLORIDE EQ 2MG BASE/ML SOLUTION INTRAVENOUS',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 0.035MG 0.035MG 0.5MG 1MG 0.5MG TABLET ORAL-21',
#  'AMIKACIN SULFATE 250MG INJECTABLE INJECTION',
#  'ARSENIC TRIOXIDE 1MG INJECTABLE INJECTION',
#  'ETOPOSIDE PHOSPHATE 100MG INJECTABLE INJECTION',
#  'RESERPINE  TRICHLORMETHIAZIDE 0.1MG 4MG TABLET ORAL',
#  'DOXERCALCIFEROL 2.5 CAPSULE ORAL',
#  'NALOXONE HYDROCHLORIDE 2MG/0.4ML SOLUTION INTRAMUSCULAR SUBCUTANEOUS',
#  'OXYTETRACYCLINE CALCIUM 125MG 5ML SYRUP ORAL',
#  'OXTRIPHYLLINE 600MG TABLET EXTENDED RELEASE ORAL',
#  'SECOBARBITAL SODIUM 50MG INJECTABLE INJECTION',
#  'ACETAMINOPHEN  PROPOXYPHENE HYDROCHLORIDE 325MG 2.5MG TABLET ORAL',
#  'EDARAVONE 0.3MG/ML SOLUTION IV INFUSION',
#  'CARMUSTINE 100MG INJECTABLE INJECTION',
#  'LEVORPHANOL TARTRATE 2MG INJECTABLE INJECTION',
#  'CHLORTHALIDONE  METOPROLOL TARTRATE 25MG 200MG CAPSULE ORAL',
#  'TECHNETIUM TC-99M SESTAMIBI KIT 0-3 INJECTABLE INJECTION',
#  'METAPROTERENOL SULFATE 0.6 0% SOLUTION INHALATION',
#  'FLUDEOXYGLUCOSE F-18 0-3 INJECTABLE INTRAVENOUS',
#  'ETHINYL ESTRADIOL  FERROUS FUMARATE  NORETHINDRONE ACETATE 0.05MG 75MG 1MG TABLET ORAL-28',
#  'NAPROXEN SODIUM 500MG TABLET ORAL',
#  'CANAGLIFLOZIN  METFORMIN HYDROCHLORIDE 50MG 1GM TABLET ORAL',
#  'TESTOSTERONE ENANTHATE 100MG INJECTABLE INJECTION',
#  'NALOXONE HYDROCHLORIDE 2MG SPRAY METERED NASAL',
#  'CALCITONIN HUMAN 0.5MG INJECTABLE INJECTION',
#  'METOPROLOL TARTRATE 1MG INJECTABLE INJECTION',
#  'DESERPIDINE  HYDROCHLOROTHIAZIDE 0.125MG 25MG TABLET ORAL',
#  'FENTANYL CITRATE 0.8MG TROCHE/LOZENGE TRANSMUCOSAL',
#  'DEXTROSE  POTASSIUM CHLORIDE 5GM 100ML 300MG 100ML INJECTABLE INJECTION',
#  'LIDOCAINE 23MG FILM EXTENDED RELEASE BUCCAL',
#  'FLUPHENAZINE HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'ESCITALOPRAM OXALATE 5MG CAPSULE ORAL',
#  'PENICILLIN G BENZATHINE 300 000 INJECTABLE INJECTION',
#  'IOTHALAMATE SODIUM 80% INJECTABLE INJECTION',
#  'BECLOMETHASONE DIPROPIONATE MONOHYDRATE 0.084MG SPRAY METERED NASAL',
#  'IODIPAMIDE MEGLUMINE 0.3 0% INJECTABLE INJECTION',
#  'UROFOLLITROPIN 150 INJECTABLE INTRAMUSCULAR',
#  'AMINOPHYLLINE 400MG 100ML INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE  SALMETEROL XINAFOATE 0.055MG 0.014MG POWDER INHALATION',
#  'WARFARIN SODIUM 25MG TABLET ORAL',
#  'SUPROFEN 1% SOLUTION/DROPS OPHTHALMIC',
#  'TETRACYCLINE HYDROCHLORIDE 1% SUSPENSION/DROPS OPHTHALMIC',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 3.75MG 3.75MG 3.75MG 3.75MG CAPSULE ORAL',
#  'SODIUM IODIDE I-131 50uCi CAPSULE ORAL',
#  'FAMOTIDINE 10MG TABLET CHEWABLE ORAL',
#  'LINAGLIPTIN  METFORMIN HYDROCHLORIDE 5MG 1GM TABLET EXTENDED RELEASE ORAL',
#  'DESOXIMETASONE 0.0 5% CREAM TOPICAL',
#  'PARGYLINE HYDROCHLORIDE 25MG TABLET ORAL',
#  'STREPTOMYCIN SULFATE 1GM 2ML INJECTABLE INJECTION',
#  'PYRVINIUM PAMOATE 50MG TABLET ORAL',
#  'AZILSARTAN KAMEDOXOMIL 40MG TABLET ORAL',
#  'AMPHOTERICIN B 50MG INJECTABLE LIPID COMPLEX INJECTION',
#  'CLINDAMYCIN PHOSPHATE 6MG INJECTABLE INJECTION',
#  'SOMATROPIN 4 IU/VIAL INJECTABLE INJECTION',
#  'MORPHINE SULFATE 8MG/ML SOLUTION INTRAMUSCULAR INTRAVENOUS',
#  'HYDROCHLOROTHIAZIDE 100MG SOLUTION ORAL',
#  'INSULIN ZINC SUSP SEMISYNTHETIC PURIFIED HUMAN 100 INJECTABLE INJECTION',
#  'FLUOCINONIDE 0.0 5% SOLUTION TOPICAL',
#  'VIOMYCIN SULFATE 1GM INJECTABLE INJECTION',
#  'CHLOROTRIANISENE 72MG CAPSULE ORAL',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 14 07 14 CAPSULE DELAYED RELEASE ORAL',
#  'NEOMYCIN SULFATE 100% POWDER FOR RX COMPOUNDING',
#  'SODIUM FLUORIDE F-18 0-2 INJECTABLE INTRAVENOUS',
#  'CITRIC ACID  UREA C-13 4GM 75MG FOR SOLUTION TABLET FOR SOLUTION ORAL',
#  'GLUCAGON RECOMBINANT 1MG INJECTABLE INJECTION',
#  'HYDROMORPHONE HYDROCHLORIDE 2MG INJECTABLE INJECTION',
#  'VANCOMYCIN HYDROCHLORIDE 10GM INJECTABLE INJECTION',
#  'LIRAGLUTIDE RECOMBINANT 6MG/ML SOLUTION SUBCUTANEOUS',
#  'ERYTHROMYCIN GLUCEPTATE 250MG INJECTABLE INJECTION',
#  'ISONIAZID 100MG INJECTABLE INJECTION',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 1.25MG 1.25MG 1.25MG 1.25MG TABLET ORAL',
#  'HYDROCORTISONE SODIUM SUCCINATE 250MG INJECTABLE INJECTION',
#  'LEUCOVORIN CALCIUM 3MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 10GM 100ML 75MG 100ML 200MG 100ML INJECTABLE INJECTION',
#  'LANTHANUM CARBONATE 1GM POWDER ORAL',
#  'DEXTROSE  MAGNESIUM ACETATE TETRAHYDRATE  POTASSIUM ACETATE  SODIUM CHLORIDE 5GM 100ML 32MG 100ML 128MG 100ML 234MG 100ML INJECTABLE INJECTION',
#  'ARGATROBAN 1MG/ML INJECTABLE IV INFUSION',
#  'DINOPROSTONE 0.5MG 3GM GEL ENDOCERVICAL',
#  'HEXACHLOROPHENE 480MG SPONGE TOPICAL',
#  'CITALOPRAM HYDROBROMIDE 10MG TABLET ORALLY DISINTEGRATING ORAL',
#  'NALIDIXIC ACID 250MG 5ML SUSPENSION ORAL',
#  'ISOPROTERENOL HYDROCHLORIDE 0.5 0% SOLUTION INHALATION',
#  'FUROSEMIDE 10MG INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 5.8MG INJECTABLE INJECTION',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 02 80 87 CAPSULE DELAYED RELEASE ORAL',
#  'PREDNISOLONE SODIUM PHOSPHATE 0.9 SOLUTION/DROPS OPHTHALMIC',
#  'ETHCHLORVYNOL 100MG CAPSULE ORAL',
#  'PENICILLIN G SODIUM 50 00 INJECTABLE INJECTION',
#  'VITAMIN A PALMITATE 50 CAPSULE ORAL',
#  'OXYMORPHONE HYDROCHLORIDE 1.5MG INJECTABLE INJECTION',
#  'LEVOBUPIVACAINE HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  LABETALOL HYDROCHLORIDE 25MG 400MG TABLET ORAL',
#  'LIDOCAINE HYDROCHLORIDE  OXYTETRACYCLINE 2% 125MG INJECTABLE INJECTION',
#  'MORPHINE SULFATE 10MG/ML INJECTABLE LIPOSOMAL EPIDURAL',
#  'ACETAMINOPHEN  CLEMASTINE FUMARATE  PSEUDOEPHEDRINE HYDROCHLORIDE 500MG 0.25MG 30MG TABLET ORAL',
#  'MYCOPHENOLATE MOFETIL 200MG SUSPENSION ORAL',
#  'ONDANSETRON HYDROCHLORIDE 2MG INJECTABLE INJECTION',
#  'MOXALACTAM DISODIUM 250MG INJECTABLE INJECTION',
#  'CHLORAMPHENICOL  HYDROCORTISONE ACETATE 2.5MG 25MG FOR SUSPENSION OPHTHALMIC',
#  'ADAPALENE 0.1 0% CREAM TOPICAL',
#  'METHYLDOPA 250MG 5ML SUSPENSION ORAL',
#  'ERYTHROMYCIN 1.5 0% SOLUTION TOPICAL',
#  'SAFFLOWER OIL  SOYBEAN OIL 10GM/100ML INJECTABLE INJECTION',
#  'THYROGLOBULIN 32MG TABLET ORAL',
#  'TECHNETIUM TC-99M SODIUM PERTECHNETATE GENERATOR 0.0 083 2.7 SOLUTION INTRAVENOUS',
#  'POTASSIUM CHLORIDE 1.49GM 100ML INJECTABLE INJECTION',
#  'DIATRIZOATE MEGLUMINE  DIATRIZOATE SODIUM 52% 8% INJECTABLE INJECTION',
#  'FENTANYL CITRATE 0.2MG TROCHE/LOZENGE ORAL',
#  'CIMETIDINE HYDROCHLORIDE 480MG 100ML INJECTABLE INJECTION',
#  'INSULIN ASPART PROTAMINE RECOMBINANT  INSULIN ASPART RECOMBINANT 50 UNITS/ML 50 UNITS/ML INJECTABLE SUBCUTANEOUS',
#  'HYDROMORPHONE HYDROCHLORIDE 12MG CAPSULE EXTENDED RELEASE ORAL',
#  'CIPROFLOXACIN 60MG/ML INJECTABLE SUSPENSION OTIC',
#  'BUTABARBITAL SODIUM 50MG CAPSULE ORAL',
#  'SOMATROPIN RECOMBINANT 0.2MG INJECTABLE INJECTION',
#  'BENDROFLUMETHIAZIDE 10MG TABLET ORAL',
#  'TETRACYCLINE HYDROCHLORIDE 50MG TABLET ORAL',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 00 68 00 CAPSULE DELAYED RELEASE ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 75MG 100ML 110MG 100ML INJECTABLE INJECTION',
#  'METHAMPHETAMINE HYDROCHLORIDE 10MG TABLET ORAL',
#  'THEOPHYLLINE 40MG 100ML INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.05MG SPRAY METERED NASAL',
#  'IOFLUPANE I-123 2mCi/ML SOLUTION INTRAVENOUS',
#  'AMPHOTERICIN B 100MG INJECTABLE LIPID COMPLEX INJECTION',
#  'DOXERCALCIFEROL 0.5 CAPSULE ORAL',
#  'CEFTAROLINE FOSAMIL 400MG POWDER IV INFUSION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 4.5MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'AMPICILLIN/AMPICILLIN TRIHYDRATE 250MG CAPSULE ORAL',
#  'TECHNETIUM TC-99M ALBUMIN AGGREGATED KIT nan INJECTABLE INJECTION',
#  'TRYPAN BLUE 0.1 5% SOLUTION OPHTHALMIC',
#  'HYDROCORTISONE ACETATE 0.5 0% OINTMENT OPHTHALMIC',
#  'CLINDAMYCIN PHOSPHATE 900MG 100ML INJECTABLE INJECTION',
#  'DESOXIMETASONE 0.0 5% OINTMENT TOPICAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 110MG 100ML 330MG 100ML INJECTABLE INJECTION',
#  'TESTOSTERONE 25MG INJECTABLE INJECTION',
#  'DIATRIZOATE SODIUM 25% INJECTABLE INJECTION',
#  'CANDESARTAN CILEXETIL  HYDROCHLOROTHIAZIDE 16MG 2.5MG TABLET ORAL',
#  'METOCLOPRAMIDE HYDROCHLORIDE 10MG CONCENTRATE ORAL',
#  'METAPROTERENOL SULFATE 0.65MG AEROSOL METERED INHALATION',
#  'GLYBURIDE 1.2 TABLET ORAL',
#  'ACETAMINOPHEN  CODEINE PHOSPHATE 325MG 15MG TABLET ORAL',
#  'HISTRELIN ACETATE 1MG INJECTABLE INJECTION',
#  'DILTIAZEM MALATE  ENALAPRIL MALEATE 180MG 5MG TABLET EXTENDED RELEASE ORAL',
#  'CEFTRIAXONE SODIUM 100GM INJECTABLE INJECTION',
#  'OXYPHENBUTAZONE 100MG TABLET ORAL',
#  'DESOXIMETASONE 0.0 5% GEL TOPICAL',
#  'TRIAMCINOLONE ACETONIDE 0.1MG AEROSOL METERED INHALATION',
#  'AMOXICILLIN  CLAVULANATE POTASSIUM 200MG 8.5MG TABLET CHEWABLE ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 33MG 100ML 5GM 100ML 30MG 100ML 860MG 100ML INJECTABLE INJECTION',
#  'TRIFLUPROMAZINE HYDROCHLORIDE 10MG TABLET ORAL',
#  'IDARUBICIN HYDROCHLORIDE 10MG INJECTABLE INJECTION',
#  'MICONAZOLE NITRATE 2% 1.2GM CREAM SUPPOSITORY TOPICAL VAGINAL',
#  'SUTILAINS 20 OINTMENT TOPICAL',
#  'CEFAMANDOLE NAFATE 10GM INJECTABLE INJECTION',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 00 60 90 CAPSULE DELAYED RELEASE ORAL',
#  'TIAGABINE HYDROCHLORIDE 6MG TABLET ORAL',
#  'SILDENAFIL CITRATE 10MG FOR SUSPENSION ORAL',
#  'LEUPROLIDE ACETATE 45MG INJECTABLE SUBCUTANEOUS',
#  'PROCHLORPERAZINE MALEATE 30MG CAPSULE EXTENDED RELEASE ORAL',
#  'IOHEXOL 1.8 0% SOLUTION INJECTION ORAL RECTAL',
#  'VERTEPORFIN 15MG INJECTABLE INJECTION',
#  'GONADOTROPIN CHORIONIC 20 INJECTABLE INJECTION',
#  'TAZAROTENE 0.1 0% GEL TOPICAL',
#  'LEVOCARNITINE 200MG INJECTABLE INJECTION',
#  'PHENMETRAZINE HYDROCHLORIDE 50MG TABLET EXTENDED RELEASE ORAL',
#  'FLUOXETINE HYDROCHLORIDE 90MG CAPSULE DELAYED REL PELLETS ORAL',
#  'PROMAZINE HYDROCHLORIDE 30MG CONCENTRATE ORAL',
#  'BETAMETHASONE BENZOATE 0.0 3% GEL TOPICAL',
#  'DOXYCYCLINE HYCLATE 100MG INJECTABLE INJECTION',
#  'DICUMAROL 25MG CAPSULE ORAL',
#  'ACYCLOVIR SODIUM 25MG INJECTABLE INJECTION',
#  'MICONAZOLE 10MG INJECTABLE INJECTION',
#  'TACROLIMUS 0.1 0% OINTMENT TOPICAL',
#  'NICOTINE POLACRILEX 2MG GUM CHEWING BUCCAL',
#  'CARBOPROST TROMETHAMINE 0.25MG INJECTABLE INJECTION',
#  'DEXTROSE 20GM 100ML INJECTABLE INJECTION',
#  'OXPRENOLOL HYDROCHLORIDE 80MG CAPSULE ORAL',
#  'ICATIBANT ACETATE EQ 10MG BASE/ML INJECTABLE SUBCUTANEOUS',
#  'ESTRADIOL  NORETHINDRONE ACETATE 0.05MG 0.25MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'PENTETATE ZINC TRISODIUM EQ 200MG BASE/ML SOLUTION INHALATION INTRAVENOUS',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 220MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 220MG 100ML 110MG 100ML INJECTABLE INJECTION',
#  'SUCCINYLCHOLINE CHLORIDE 100MG INJECTABLE INJECTION',
#  'CEFOPERAZONE SODIUM 20MG INJECTABLE INJECTION',
#  'INDIUM IN-111 PENTETATE DISODIUM 1mCi/ML INJECTABLE INTRATHECAL',
#  'PROPRANOLOL HYDROCHLORIDE 80MG CONCENTRATE ORAL',
#  'DESMETHYL PIROXICAM 10MG CAPSULE ORAL',
#  'AZITHROMYCIN 500MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 298MG 100ML 300MG 100ML INJECTABLE INJECTION',
#  'AMINOPHYLLINE 100MG 100ML INJECTABLE INJECTION',
#  'ESTRADIOL VALERATE 10MG INJECTABLE INJECTION',
#  'CEFADROXIL/CEFADROXIL HEMIHYDRATE 125MG 5ML FOR SUSPENSION ORAL',
#  'MORPHINE SULFATE 0.5MG INJECTABLE INJECTION',
#  'PAROMOMYCIN SULFATE 125MG 5ML SYRUP ORAL',
#  'HYDROCHLOROTHIAZIDE  QUINAPRIL HYDROCHLORIDE 2.5MG 10MG TABLET ORAL',
#  'AMPHOTERICIN B 5MG INJECTABLE LIPID COMPLEX INJECTION',
#  'AMIKACIN SULFATE 2.5MG INJECTABLE INJECTION',
#  'MIDAZOLAM HYDROCHLORIDE 2MG SYRUP ORAL',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 1.05MG 100MG PATCH IONTOPHORESIS TOPICAL',
#  'VASOPRESSIN 20UNITS/ML SOLUTION IV INFUSION',
#  'GLUTAMINE 5GM FOR SOLUTION ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 0.03MG 0.035MG 1MG 1MG 1MG TABLET ORAL-28',
#  'HYDROMORPHONE HYDROCHLORIDE 32MG CAPSULE EXTENDED RELEASE ORAL',
#  'NANDROLONE PHENPROPIONATE 25MG INJECTABLE INJECTION',
#  'IODIXANOL 5.2 0% INJECTABLE INJECTION',
#  'BUTORPHANOL TARTRATE 2MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 0.03MG 0.035MG 1MG 1MG 1MG TABLET ORAL-21',
#  'ATROPINE SULFATE  MEPERIDINE HYDROCHLORIDE 0.4MG 75MG INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE  SALMETEROL XINAFOATE 0.1MG 0.05MG POWDER INHALATION',
#  'HYDRALAZINE HYDROCHLORIDE  RESERPINE 25MG 0.1MG TABLET ORAL',
#  'MEPIVACAINE HYDROCHLORIDE 2% INJECTABLE INJECTION',
#  'ALCLOMETASONE DIPROPIONATE 0.0 5% CREAM TOPICAL',
#  'DESMOPRESSIN ACETATE 0.00166MG SPRAY METERED NASAL',
#  'METOCLOPRAMIDE HYDROCHLORIDE 5MG TABLET ORALLY DISINTEGRATING ORAL',
#  'AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE  OLMESARTAN MEDOXOMIL 10MG 2.5MG 40MG TABLET ORAL',
#  'OXACILLIN SODIUM 250MG 5ML FOR SOLUTION ORAL',
#  'DANAPAROID SODIUM 750 0.6ML INJECTABLE INJECTION',
#  'ISOETHARINE MESYLATE 0.34MG AEROSOL METERED INHALATION',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 300MG 100ML INJECTABLE INJECTION',
#  'ALBUMIN IODINATED I-131 SERUM 1mCi/VIAL INJECTABLE INJECTION',
#  'CYCLOPHOSPHAMIDE 1GM INJECTABLE INJECTION',
#  'TENOFOVIR DISOPROXIL FUMARATE 40MG POWDER ORAL',
#  'FLUTICASONE PROPIONATE 0.11MG AEROSOL METERED INHALATION',
#  'TREPROSTINIL 10MG INJECTABLE IV INFUSION SUBCUTANEOUS',
#  'CEFAMANDOLE NAFATE 1GM INJECTABLE INJECTION',
#  'BETAMETHASONE BENZOATE 0.0 3% LOTION TOPICAL',
#  'LEUCOVORIN CALCIUM 5MG INJECTABLE INJECTION',
#  'PHENYTOIN SODIUM 200MG CAPSULE ORAL',
#  'MESNA 100MG INJECTABLE INTRAVENOUS',
#  'THEOPHYLLINE 4MG INJECTABLE INJECTION',
#  'INVERT SUGAR 10GM 100ML INJECTABLE INJECTION',
#  'ETHOPROPAZINE HYDROCHLORIDE 10MG TABLET ORAL',
#  'METHADONE HYDROCHLORIDE 5MG TABLET EFFERVESCENT ORAL',
#  'DEXTROMETHORPHAN HYDROBROMIDE  GUAIFENESIN 60MG 1.2GM TABLET EXTENDED RELEASE ORAL',
#  'PROMAZINE HYDROCHLORIDE 100MG TABLET ORAL',
#  'METHYCLOTHIAZIDE  PARGYLINE HYDROCHLORIDE 5MG 25MG TABLET ORAL',
#  'MAGNESIUM SULFATE  POTASSIUM SULFATE  SODIUM SULFATE 1.6GM 3.13GM 7.5GM POWDER ORAL',
#  'AMINOSALICYLATE SODIUM 1GM TABLET ORAL',
#  'TECHNETIUM TC-99M LIDOFENIN KIT nan INJECTABLE INJECTION',
#  'ENOXAPARIN SODIUM 150MG/ML INJECTABLE SUBCUTANEOUS',
#  'THEOPHYLLINE SODIUM GLYCINATE 165MG 15ML ELIXIR ORAL',
#  'ROCURONIUM BROMIDE 10MG/ML INJECTABLE INJECTION',
#  'PEGAPTANIB SODIUM 0.3MG 0.09ML INJECTABLE INTRAVITREAL',
#  'HYDROCORTISONE BUTYRATE 0.1 0% CREAM TOPICAL',
#  'METHADONE HYDROCHLORIDE 50GM POWDER FOR RX COMPOUNDING',
#  'FOLIC ACID 5MG INJECTABLE INJECTION',
#  'TESTOSTERONE CYPIONATE 200MG INJECTABLE INJECTION',
#  'CHLORPROMAZINE HYDROCHLORIDE 300MG CAPSULE EXTENDED RELEASE ORAL',
#  'HALCINONIDE 0.1 0% CREAM TOPICAL',
#  'NAFCILLIN SODIUM 2GM INJECTABLE INJECTION',
#  'LIDOCAINE HYDROCHLORIDE 1.5 0% INJECTABLE SPINAL',
#  'METHYL AMINOLEVULINATE HYDROCHLORIDE 6.8 CREAM TOPICAL',
#  'QUINIDINE GLUCONATE 330MG TABLET EXTENDED RELEASE ORAL',
#  'TRAMADOL HYDROCHLORIDE 100MG TABLET ORAL',
#  'CORTICOTROPIN-ZINC HYDROXIDE 40 UNITS/ML INJECTABLE INJECTION',
#  'COLESEVELAM HYDROCHLORIDE 3.75GM FOR SUSPENSION ORAL',
#  'MORPHINE SULFATE 4MG INJECTABLE INJECTION',
#  'METHICILLIN SODIUM 3.6GM INJECTABLE INJECTION',
#  'PREDNISOLONE SODIUM PHOSPHATE 15MG TABLET ORALLY DISINTEGRATING ORAL',
#  'TAZAROTENE 0.1 0% AEROSOL FOAM TOPICAL',
#  'OXYMETAZOLINE HYDROCHLORIDE  TETRACAINE HYDROCHLORIDE 0.1MG 6MG SPRAY METERED NASAL',
#  'SPECTINOMYCIN HYDROCHLORIDE 4GM INJECTABLE INJECTION',
#  'ASPIRIN  PRAVASTATIN SODIUM 325MG 80MG TABLET TABLET ORAL',
#  'OFLOXACIN 0.3 0% SOLUTION/DROPS OTIC',
#  'CEPHAPIRIN SODIUM 500MG INJECTABLE INJECTION',
#  'LANSOPRAZOLE 15MG FOR SUSPENSION DELAYED RELEASE ORAL',
#  'METRIZAMIDE 6.75GM INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 300MG 100ML 200MG 100ML INJECTABLE INJECTION',
#  'SAFFLOWER OIL 20GM/100ML INJECTABLE INJECTION',
#  'NIACIN 375MG 500MG 750MG TABLET EXTENDED RELEASE ORAL',
#  'NYSTATIN 100 000 OINTMENT TOPICAL',
#  'CYCLACILLIN 500MG TABLET ORAL',
#  'TRIPELENNAMINE HYDROCHLORIDE 100MG TABLET EXTENDED RELEASE ORAL',
#  'XYLOSE 25GM POWDER ORAL',
#  'AMINO ACIDS  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 4.2 5% 25GM 100ML 51MG 100ML 2.4MG 100ML 261MG 100ML 205MG 100ML INJECTABLE INJECTION',
#  'EPINEPHRINE 0.3MG/ML SOLUTION INTRAMUSCULAR SUBCUTANEOUS',
#  'TECHNETIUM TC-99M SODIUM PERTECHNETATE GENERATOR 830 166 SOLUTION INTRAVENOUS ORAL',
#  'HEPARIN SODIUM 500 100ML INJECTABLE INJECTION',
#  'THEOPHYLLINE SODIUM GLYCINATE 150MG TABLET ORAL',
#  'IODOXAMATE MEGLUMINE 0.3 0% INJECTABLE INJECTION',
#  'METAPROTERENOL SULFATE 0.3 3% SOLUTION INHALATION',
#  'SULFISOXAZOLE ACETYL 500MG 5ML SUSPENSION ORAL',
#  'FENTANYL HYDROCHLORIDE EQ 40MCG BASE/ACTIVATION SYSTEM IONTOPHORESIS TRANSDERMAL',
#  'CEFOTETAN DISODIUM 40MG INJECTABLE INJECTION',
#  'CIPROFLOXACIN HYDROCHLORIDE  FLUOCINOLONE ACETONIDE 0.3 0.0 25% SOLUTION/DROPS OTIC',
#  'PROPOXYPHENE HYDROCHLORIDE 32MG CAPSULE ORAL',
#  'OXPRENOLOL HYDROCHLORIDE 160MG CAPSULE ORAL',
#  'PREDNISOLONE 0.5 0% CREAM TOPICAL',
#  'COLISTIN SULFATE  HYDROCORTISONE ACETATE  NEOMYCIN SULFATE  THONZONIUM BROMIDE 3MG 10MG 3.3MG 0.5MG SUSPENSION/DROPS OTIC',
#  'ACETAMINOPHEN  TRAMADOL HYDROCHLORIDE 325MG 7.5MG TABLET ORAL',
#  'CEFOTIAM HYDROCHLORIDE 1GM INJECTABLE INJECTION',
#  'NYSTATIN 100% POWDER ORAL',
#  'PENICILLIN G BENZATHINE 600 000 INJECTABLE INJECTION',
#  'DESMOPRESSIN ACETATE 0.00083MG SPRAY METERED NASAL',
#  'TRAVOPROST 0.0 04% SOLUTION/DROPS OPHTHALMIC',
#  'IFOSFAMIDE  MESNA 3GM 100MG INJECTABLE INJECTION',
#  'LIOTRIX T4 T3 0.06MG 0.015MG TABLET ORAL',
#  'ATROPINE 0.25MG 0.3ML INJECTABLE INJECTION',
#  'MANGAFODIPIR TRISODIUM 7.9MG INJECTABLE INJECTION',
#  'OXACILLIN SODIUM 125MG INJECTABLE INJECTION',
#  'UROFOLLITROPIN 75 IU/VIAL INJECTABLE INTRAMUSCULAR SUBCUTANEOUS',
#  'PENICILLIN G SODIUM 50 00 INJECTABLE INTRAMUSCULAR INTRAVENOUS',
#  'HYDROCHLOROTHIAZIDE  QUINAPRIL HYDROCHLORIDE 2.5MG 20MG TABLET ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE 5GM 100ML 298MG 100ML INJECTABLE INJECTION',
#  'FLUDEOXYGLUCOSE F-18 4-4 INJECTABLE INTRAVENOUS',
#  'TRIAMCINOLONE ACETONIDE 0.1 0% PASTE DENTAL',
#  'BACITRACIN ZINC  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 500 3.5MG 00 OINTMENT OPHTHALMIC',
#  'ZOLEDRONIC ACID 4MG 100ML INJECTABLE IV INFUSION',
#  'TAPENTADOL HYDROCHLORIDE 20MG SOLUTION ORAL',
#  'PREDNISOLONE ACETATE 25MG INJECTABLE INJECTION',
#  'HEPARIN SODIUM 10 UNITS/ML INJECTABLE INJECTION',
#  'AMITRIPTYLINE HYDROCHLORIDE  CHLORDIAZEPOXIDE 2.5MG 5MG TABLET ORAL',
#  'MORPHINE SULFATE 2MG/ML SOLUTION INTRAMUSCULAR INTRAVENOUS',
#  'ERYTHROMYCIN ESTOLATE 100MG SUSPENSION/DROPS ORAL',
#  'ALMOTRIPTAN MALATE 2.5MG TABLET ORAL',
#  'TOPIRAMATE 300MG TABLET ORAL',
#  'ALBUTEROL SULFATE 0.2MG CAPSULE INHALATION',
#  'SERTRALINE HYDROCHLORIDE 20MG CONCENTRATE ORAL',
#  'PENBUTOLOL SULFATE 10MG TABLET ORAL',
#  'TOBRAMYCIN 28MG POWDER INHALATION',
#  'PREDNISOLONE ACETATE 40MG INJECTABLE INJECTION',
#  'HEPARIN SODIUM 20 INJECTABLE INJECTION',
#  'PENICILLIN G POTASSIUM 200 000 INJECTABLE INJECTION',
#  'SIMVASTATIN  SITAGLIPTIN PHOSPHATE 40MG 100MG TABLET ORAL',
#  'ROTIGOTINE 6MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'AZELASTINE HYDROCHLORIDE 0.0 5% SOLUTION/DROPS OPHTHALMIC',
#  'BROMPHENIRAMINE MALEATE 10MG INJECTABLE INJECTION',
#  'INSULIN GLULISINE RECOMBINANT 100 UNITS/ML INJECTABLE IV INFUSION SUBCUTANEOUS',
#  'AMMONIA N-13 3.75-37.5mCi/ML INJECTABLE INTRAVENOUS',
#  'OLANZAPINE PAMOATE 405MG SUSPENSION EXTENDED RELEASE INTRAMUSCULAR',
#  'DIAZEPAM 5MG INJECTABLE INJECTION',
#  'DEXRAZOXANE HYDROCHLORIDE 500MG INJECTABLE INJECTION',
#  'INSULIN SUSP ISOPHANE PURIFIED BEEF 100 INJECTABLE INJECTION',
#  'SALMETEROL XINAFOATE 0.021MG AEROSOL METERED INHALATION',
#  'SUFENTANIL CITRATE 0.05MG INJECTABLE INJECTION',
#  'DEXTROTHYROXINE SODIUM 1MG TABLET ORAL',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.01MG 2% INJECTABLE INJECTION',
#  'MAGNESIUM HYDROXIDE  OMEPRAZOLE  SODIUM BICARBONATE 343MG 20MG 750MG TABLET ORAL',
#  'CALCIUM CHLORIDE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM CITRATE 35MG 100ML 30MG 100ML 74MG 100ML 640MG 100ML 500MG 100ML 74MG 100ML INJECTABLE INJECTION',
#  'INDOCYANINE GREEN 10MG INJECTABLE INJECTION',
#  'CARBIDOPA  LEVODOPA 1.25MG 245MG CAPSULE EXTENDED RELEASE ORAL',
#  'TRIFLUPROMAZINE HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'CHLORMEZANONE 100MG TABLET ORAL',
#  'ARDEPARIN SODIUM 00 0.5ML INJECTABLE INJECTION',
#  'IFOSFAMIDE 1GM INJECTABLE INJECTION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 4.2 5% 33MG 100ML 20GM 100ML 51MG 100ML 261MG 100ML 297MG 100ML 77MG 100ML INJECTABLE INJECTION',
#  'CORTISONE ACETATE 25MG INJECTABLE INJECTION',
#  'CYANOCOBALAMIN 1MG INJECTABLE INJECTION',
#  'CYANOCOBALAMIN CO-57 0.5 CAPSULE ORAL',
#  'ETOPOSIDE PHOSPHATE 500MG INJECTABLE INJECTION',
#  'ISONIAZID 25MG INJECTABLE INJECTION',
#  'DEXTROTHYROXINE SODIUM 6MG TABLET ORAL',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.25MG TABLET ORAL-28',
#  'SOMATROPIN 2 IU/VIAL INJECTABLE INJECTION',
#  'DIDANOSINE 100MG TABLET FOR SUSPENSION ORAL',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.25MG TABLET ORAL-21',
#  'QUINIDINE SULFATE 200MG CAPSULE ORAL',
#  'THEOPHYLLINE 80MG 15ML SYRUP ORAL',
#  'KETOROLAC TROMETHAMINE 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'IOTHALAMATE SODIUM 4.3 0% INJECTABLE INJECTION',
#  'HEPARIN SODIUM 00 100ML INJECTABLE INJECTION',
#  'TACROLIMUS 5MG INJECTABLE INJECTION',
#  'BUPRENORPHINE HYDROCHLORIDE  NALOXONE HYDROCHLORIDE 1.4MG 2.9MG TABLET SUBLINGUAL',
#  'METHACYCLINE HYDROCHLORIDE 280MG CAPSULE ORAL',
#  'ATROPINE SULFATE 0.36MG AEROSOL METERED INHALATION',
#  'CHLORAMPHENICOL SODIUM SUCCINATE 1GM INJECTABLE INJECTION',
#  'PENICILLIN G POTASSIUM 200 000 TABLET ORAL',
#  'PINACIDIL 2.5MG CAPSULE EXTENDED RELEASE ORAL',
#  'PAROXETINE HYDROCHLORIDE 30MG CAPSULE ORAL',
#  'DEXRAZOXANE HYDROCHLORIDE 250MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 10GM 100ML 150MG 100ML 450MG 100ML INJECTABLE INJECTION',
#  'FLUOROURACIL 50MG INJECTABLE INJECTION',
#  'AZTREONAM 75MG FOR SOLUTION INHALATION',
#  'BUPRENORPHINE HYDROCHLORIDE  NALOXONE HYDROCHLORIDE 2MG 0.5MG FILM BUCCAL SUBLINGUAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 3.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'SOMATROPIN RECOMBINANT 4.8MG INJECTABLE INJECTION',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE  TRIPROLIDINE HYDROCHLORIDE 120MG 5MG TABLET EXTENDED RELEASE ORAL',
#  'AMINO ACIDS  MAGNESIUM CHLORIDE  POTASSIUM ACETATE  POTASSIUM CHLORIDE  SODIUM ACETATE 8% 61MG 100ML 211MG 100ML 56MG 100ML 388MG 100ML INJECTABLE INJECTION',
#  'CHOLESTYRAMINE 1GM TABLET ORAL',
#  'CHLOROQUINE HYDROCHLORIDE 40MG INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M ETIDRONATE KIT nan INJECTABLE INJECTION',
#  'CHLORHEXIDINE GLUCONATE 4% AEROSOL METERED TOPICAL',
#  'TECHNETIUM TC-99M SULFUR COLLOID KIT nan SOLUTION INJECTION ORAL',
#  'ASPIRIN  PRAVASTATIN SODIUM 325MG 40MG TABLET TABLET TABLET ORAL',
#  'CARTEOLOL HYDROCHLORIDE 10MG TABLET ORAL',
#  'FURAZOLIDONE 100MG TABLET ORAL',
#  'CALCITONIN SALMON 400 INJECTABLE INJECTION',
#  'DILTIAZEM HYDROCHLORIDE 100MG INJECTABLE INJECTION',
#  'HALOPERIDOL LACTATE 2MG CONCENTRATE ORAL',
#  'EPROSARTAN MESYLATE  HYDROCHLOROTHIAZIDE 600MG 2.5MG TABLET ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.01MG 0.01MG 1MG TABLET CHEWABLE TABLET ORAL',
#  'DEXAMETHASONE 1MG CONCENTRATE ORAL',
#  'INDACATEROL MALEATE EQ 75MCG BASE POWDER INHALATION',
#  'SULFAPHENAZOLE 500MG 5ML SUSPENSION ORAL',
#  'TERBUTALINE SULFATE 0.2MG AEROSOL METERED INHALATION',
#  'DEXTROSE 7.7GM 100ML INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  FERROUS FUMARATE  NORETHINDRONE 0.035MG 75MG 1MG TABLET ORAL-28',
#  'METFORMIN HYDROCHLORIDE  SITAGLIPTIN PHOSPHATE 1GM 50MG TABLET EXTENDED RELEASE ORAL',
#  'PENICILLIN G BENZATHINE  PENICILLIN G PROCAINE 900 000 2ML 300 000 2ML INJECTABLE INJECTION',
#  'AZTREONAM 40MG INJECTABLE INJECTION',
#  'EPINEPHRINE 5MG INJECTABLE INJECTION',
#  'LEVOFLOXACIN 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'ASPIRIN  CAFFEINE  PROPOXYPHENE HYDROCHLORIDE 389MG 2.4MG 65MG CAPSULE ORAL',
#  'HYDROCORTISONE BUTYRATE 0.1 0% SOLUTION TOPICAL',
#  'CROMOLYN SODIUM 0.8MG AEROSOL METERED INHALATION',
#  'PANCRELIPASE AMYLASE LIPASE PROTEASE 75 42 00 CAPSULE DELAYED RELEASE ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 2.5GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'CHLORPHENIRAMINE MALEATE  CODEINE PHOSPHATE 8MG 4.3MG TABLET EXTENDED RELEASE ORAL',
#  'INSULIN LISPRO RECOMBINANT 100 INJECTABLE INJECTION',
#  'CITALOPRAM HYDROBROMIDE 40MG CAPSULE ORAL',
#  'POTASSIUM CHLORIDE 2.24GM 100ML INJECTABLE INJECTION',
#  'IOVERSOL 68% INJECTABLE INJECTION',
#  'PHENTERMINE HYDROCHLORIDE 7.5MG TABLET ORALLY DISINTEGRATING ORAL',
#  'CEFTIZOXIME SODIUM 20MG INJECTABLE INJECTION',
#  'IODIPAMIDE SODIUM 20% INJECTABLE INJECTION',
#  'DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE  SODIUM LACTATE  SODIUM PHOSPHATE MONOBASIC ANHYDROUS 5GM 100ML 53MG 100ML 100MG 100ML 100MG 100ML 180MG 100ML 280MG 100ML 16MG 100ML INJECTABLE INJECTION',
#  "RIBOFLAVIN 5'-PHOSPHATE SODIUM 0.1 5% SOLUTION/DROPS OPHTHALMIC",
#  'TESTOSTERONE 100MG INJECTABLE INJECTION',
#  'METHOTREXATE SODIUM 1GM INJECTABLE INJECTION',
#  'CRYPTENAMINE ACETATES 260 INJECTABLE INJECTION',
#  'GENTAMICIN SULFATE 2MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.05MG 1MG TABLET ORAL-28',
#  'CABOZANTINIB S-MALATE 80MG CAPSULE ORAL',
#  'OXACILLIN SODIUM 1GM POWDER INTRAVENOUS',
#  'TESTOLACTONE 100MG INJECTABLE INJECTION',
#  'BECLOMETHASONE DIPROPIONATE MONOHYDRATE 0.042MG SPRAY METERED NASAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 3.3GM 100ML 110MG 100ML 300MG 100ML INJECTABLE INJECTION',
#  'TROPICAMIDE 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 224MG 100ML 330MG 100ML INJECTABLE INJECTION',
#  'ALBUTEROL SULFATE 0.090MG POWDER METERED INHALATION',
#  'BRETYLIUM TOSYLATE 50MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 5GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'BACITRACIN ZINC  LIDOCAINE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 400 40MG 5MG 50 OINTMENT TOPICAL',
#  'RESERPINE 2.5MG INJECTABLE INJECTION',
#  'ESTROGENS CONJUGATED SYNTHETIC A 0.625MG CREAM VAGINAL',
#  'PEGINESATIDE ACETATE EQ 2MG BASE/0.5ML SOLUTION INTRAVENOUS SUBCUTANEOUS',
#  'IODOHIPPURATE SODIUM I-123 1mCi/ML INJECTABLE INJECTION',
#  'METHYLPREDNISOLONE ACETATE 20MG INJECTABLE INJECTION',
#  'ALISKIREN HEMIFUMARATE  VALSARTAN 300MG 320MG TABLET ORAL',
#  'ACYCLOVIR SODIUM 250MG INJECTABLE INJECTION',
#  'IOTHALAMATE MEGLUMINE 30% INJECTABLE INJECTION',
#  'SODIUM OXYBATE 500MG SOLUTION ORAL',
#  'OXALIPLATIN 50MG INJECTABLE IV INFUSION',
#  'BACAMPICILLIN HYDROCHLORIDE 800MG TABLET ORAL',
#  'DEXTROSE 2.5GM 100ML INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M SODIUM PERTECHNETATE 12mCi/ML SOLUTION INJECTION ORAL',
#  'ANILERIDINE PHOSPHATE 25MG INJECTABLE INJECTION',
#  'ARTICAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 4%  EQ 0.005MG BASE/ML INJECTABLE INJECTION',
#  'RESERPINE  TRICHLORMETHIAZIDE 0.1MG 2MG TABLET ORAL',
#  'DIBUCAINE HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'HALCINONIDE 0.1 0% SOLUTION TOPICAL',
#  'TICARCILLIN DISODIUM 20GM INJECTABLE INJECTION',
#  'AMPICILLIN SODIUM 2GM INJECTABLE INJECTION',
#  'AMPICILLIN SODIUM 2GM POWDER INTRAVENOUS',
#  'BACITRACIN ZINC  POLYMYXIN B SULFATE 00 20 00 AEROSOL TOPICAL',
#  'PROPIOLACTONE nan SOLUTION IRRIGATION',
#  'INSULIN ZINC SUSP RECOMBINANT HUMAN 100 INJECTABLE INJECTION',
#  'AMIKACIN SULFATE 10MG INJECTABLE INJECTION',
#  'ALPRAZOLAM 1MG CONCENTRATE ORAL',
#  'MEDROXYPROGESTERONE ACETATE 100MG INJECTABLE INJECTION',
#  'FLUVOXAMINE MALEATE 150MG TABLET ORAL',
#  'DESFLURANE 9.9 0% LIQUID INHALATION',
#  'VIOMYCIN SULFATE 5GM INJECTABLE INJECTION',
#  'CISPLATIN 1MG INJECTABLE INJECTION',
#  'PRAZEPAM 5MG CAPSULE ORAL',
#  'MECHLORETHAMINE HYDROCHLORIDE 0.0 16% GEL TOPICAL',
#  'AMINOPHYLLINE 105MG 5ML SOLUTION ORAL',
#  'BARIUM SULFATE 213GM/355ML SUSPENSION ORAL',
#  'AMOXICILLIN  CLAVULANATE POTASSIUM 1GM 2.5MG TABLET EXTENDED RELEASE ORAL',
#  'INSULIN LISPRO RECOMBINANT 200 SOLUTION SUBCUTANEOUS',
#  'DESOXIMETASONE 0.2 5% CREAM TOPICAL',
#  'TRIPTORELIN PAMOATE 3.75MG INJECTABLE INTRAMUSCULAR',
#  'AMOXICILLIN  CLARITHROMYCIN  OMEPRAZOLE 500MG 500MG 20MG CAPSULE TABLET CAPSULE DELAYED RELEASE ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 224MG 100ML 225MG 100ML INJECTABLE INJECTION',
#  'ALOGLIPTIN BENZOATE  PIOGLITAZONE HYDROCHLORIDE 2.5MG 15MG TABLET ORAL',
#  'PROCAINE HYDROCHLORIDE 2% INJECTABLE INJECTION',
#  'HALOPERIDOL LACTATE 1MG SOLUTION ORAL',
#  'NITROFURAZONE 0.2 0% POWDER TOPICAL',
#  'MEROPENEM 1GM POWDER IV INFUSION',
#  'TRIMETREXATE GLUCURONATE 200MG INJECTABLE INJECTION',
#  'CLONIDINE HYDROCHLORIDE 0.1MG/ML INJECTABLE INJECTION',
#  'GONADOTROPIN CHORIONIC 00 INJECTABLE INJECTION',
#  'EPIRUBICIN HYDROCHLORIDE 2MG/ML INJECTABLE INJECTION',
#  'SAPROPTERIN DIHYDROCHLORIDE 500MG POWDER ORAL',
#  'TOLAZOLINE HYDROCHLORIDE 25MG INJECTABLE INJECTION',
#  'DIDANOSINE 375MG FOR SOLUTION ORAL',
#  'CHLORMEZANONE 200MG TABLET ORAL',
#  'TRANEXAMIC ACID 100MG INJECTABLE INJECTION',
#  'ACETAMINOPHEN  CODEINE PHOSPHATE 325MG 60MG TABLET ORAL',
#  'VENLAFAXINE HYDROCHLORIDE 7.5MG TABLET ORAL',
#  'MALATHION 0.5 0% LOTION TOPICAL',
#  'INSULIN SUSP ISOPHANE BEEF/PORK 40 UNITS/ML INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 75MG 100ML 330MG 100ML INJECTABLE INJECTION',
#  'CANDICIDIN 3MG TABLET VAGINAL',
#  'DEXTROSE  SODIUM CHLORIDE 2.5GM 100ML 330MG 100ML INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 2.5GM 100ML 5.2MG 100ML 567MG 100ML 392MG 100ML SOLUTION INTRAPERITONEAL',
#  'COSYNTROPIN 0.25MG/ML SOLUTION INTRAVENOUS',
#  'SODIUM BICARBONATE 0.5 INJECTABLE INJECTION',
#  'CLARITHROMYCIN 1GM TABLET EXTENDED RELEASE ORAL',
#  'LOVASTATIN 10MG TABLET EXTENDED RELEASE ORAL',
#  'AZELASTINE HYDROCHLORIDE 0.1876MG SPRAY METERED NASAL',
#  'OFLOXACIN 4MG INJECTABLE INJECTION',
#  'LEVALBUTEROL TARTRATE 0.045MG AEROSOL METERED INHALATION',
#  'METRONIDAZOLE 0.7 5% GEL TOPICAL',
#  'AMINO ACIDS 6.9GM/100ML INJECTABLE INJECTION',
#  'AMINOPHYLLINE 300MG 5ML ENEMA RECTAL',
#  'BRIMONIDINE TARTRATE 0.3 3% GEL TOPICAL',
#  'MAGNESIUM SULFATE  POTASSIUM SULFATE  SODIUM SULFATE 1.6GM 3.13GM 7.5GM SOLUTION ORAL',
#  'CYCLOPHOSPHAMIDE 2GM INJECTABLE INJECTION',
#  'FOSAPREPITANT DIMEGLUMINE 150MG POWDER INTRAVENOUS',
#  'DEXAMETHASONE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 0.1 3.5MG 00 SUSPENSION/DROPS OPHTHALMIC',
#  'CYCRIMINE HYDROCHLORIDE 2.5MG TABLET ORAL',
#  'TETRACYCLINE HYDROCHLORIDE 2.2MG FOR SOLUTION TOPICAL',
#  'ETHINYL ESTRADIOL  NORGESTREL 0.05MG 0.5MG TABLET ORAL-28',
#  'SELEGILINE 6MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CEFEPIME HYDROCHLORIDE EQ 20MG BASE/ML INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.22MG POWDER INHALATION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 1.5GM 100ML 5.2MG 100ML 567MG 100ML 392MG 100ML SOLUTION INTRAPERITONEAL',
#  'ETHOPROPAZINE HYDROCHLORIDE 100MG TABLET ORAL',
#  'PENICILLIN G BENZATHINE 200 000 TABLET ORAL',
#  'MAGNESIUM SULFATE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE MONOBASIC  SODIUM CHLORIDE  SODIUM PHOSPHATE 20MG 100ML 40MG 100ML 6.25MG 100ML 800MG 100ML 8.75MG 100ML SOLUTION IRRIGATION',
#  'ASPIRIN  BUTALBITAL 650MG 50MG TABLET ORAL',
#  'MOLINDONE HYDROCHLORIDE 25MG CAPSULE ORAL',
#  'FLUTICASONE PROPIONATE 0.113MG POWDER INHALATION',
#  'MANNITOL 5GM 100ML INJECTABLE INJECTION',
#  'SELENOMETHIONINE SE-75 250 INJECTABLE INJECTION',
#  'ESTRADIOL 0.0 1% CREAM VAGINAL',
#  'CALCIUM CHLORIDE  DEXTROSE  GLUTATHIONE DISULFIDE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM PHOSPHATE 0.154MG 0.92MG 0.184MG 0.2MG 0.38MG 2.1MG 7.14MG 0.42MG SOLUTION IRRIGATION',
#  'HYDROCHLOROTHIAZIDE  OLMESARTAN MEDOXOMIL 2.5MG 20MG TABLET ORAL',
#  'LANREOTIDE ACETATE EQ 90MG BASE/0.3ML SOLUTION SUBCUTANEOUS',
#  'FORMOTEROL FUMARATE  GLYCOPYRROLATE 0.0048MG 0.0090MG AEROSOL METERED INHALATION',
#  "ASCORBIC ACID  BIOTIN  CYANOCOBALAMIN  DEXPANTHENOL  ERGOCALCIFEROL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE HYDROCHLORIDE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE HYDROCHLORIDE  VITAMIN A PALMITATE  VITAMIN E 50MG 0.03MG 0.0025MG 7.5MG 100 0.2MG 20MG 2MG 1.8MG 1.5MG 16 INJECTABLE INJECTION",
#  'METRIZAMIDE 3.75GM INJECTABLE INJECTION',
#  'BUTABARBITAL SODIUM 7.2MG TABLET ORAL',
#  'HYDROCORTISONE ACETATE  NEOMYCIN SULFATE 2.5 3.5MG OINTMENT TOPICAL',
#  'ISOETHARINE HYDROCHLORIDE 0.5 0% SOLUTION INHALATION',
#  'HYDROCORTISONE 100% POWDER FOR RX COMPOUNDING',
#  'SUNITINIB MALATE 2.5MG CAPSULE ORAL',
#  'ECONAZOLE NITRATE 1% AEROSOL FOAM TOPICAL',
#  'PEMIROLAST POTASSIUM 0.1 0% SOLUTION/DROPS OPHTHALMIC',
#  'SUCCINYLCHOLINE CHLORIDE 500MG INJECTABLE INJECTION',
#  'CLINDAMYCIN PHOSPHATE 18MG INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M TEBOROXIME KIT nan INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE  TROMETHAMINE 370MG 1.75GM 36GM INJECTABLE INJECTION',
#  'HYDROXYZINE HYDROCHLORIDE 25MG INJECTABLE INJECTION',
#  'DEXMEDETOMIDINE HYDROCHLORIDE EQ 100MCG BASE/ML SOLUTION IV INFUSION',
#  'CEFADROXIL/CEFADROXIL HEMIHYDRATE 250MG CAPSULE ORAL',
#  'SODIUM CHLORIDE 0.9 0% AEROSOL METERED INHALATION',
#  'AMPICILLIN/AMPICILLIN TRIHYDRATE 125MG 5ML FOR SUSPENSION ORAL',
#  'GANCICLOVIR SODIUM 500MG INJECTABLE INJECTION',
#  'CHLORPROTHIXENE 100MG 5ML CONCENTRATE ORAL',
#  'VANCOMYCIN HYDROCHLORIDE 250MG 5ML FOR SOLUTION ORAL',
#  'DEXAMETHASONE SODIUM PHOSPHATE 20MG INJECTABLE INJECTION',
#  'DIATRIZOATE MEGLUMINE  DIATRIZOATE SODIUM 66% 10% INJECTABLE INJECTION',
#  'CLIOQUINOL  NYSTATIN 10MG 100 000 OINTMENT TOPICAL',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.005MG 0.5 INJECTABLE INJECTION',
#  'AMITRIPTYLINE HYDROCHLORIDE 40MG CONCENTRATE ORAL',
#  'ACETAMINOPHEN  OXYCODONE HYDROCHLORIDE 400MG 2.5MG TABLET ORAL',
#  'PRAZEPAM 10MG TABLET ORAL',
#  'CICLESONIDE 0.05MG SPRAY METERED NASAL',
#  'CHLORHEXIDINE GLUCONATE 2.5 0% SOLUTION TOPICAL',
#  'OXYTOCIN 10USP UNITS/ML INJECTABLE INJECTION',
#  'IOPAMIDOL 76% INJECTABLE INJECTION',
#  'BACITRACIN  POLYMYXIN B SULFATE 500 50 DISC TOPICAL',
#  'CARBIDOPA  ENTACAPONE  LEVODOPA 8.75MG 200MG 75MG TABLET ORAL',
#  'OXYTETRACYCLINE HYDROCHLORIDE 125MG CAPSULE ORAL',
#  'LOXAPINE HYDROCHLORIDE 25MG CONCENTRATE ORAL',
#  'NALBUPHINE HYDROCHLORIDE 10MG INJECTABLE INJECTION',
#  'DEFIBROTIDE SODIUM 80MG/ML SOLUTION IV INFUSION',
#  'CEFTRIAXONE SODIUM  LIDOCAINE 500MG 1% INJECTABLE INJECTION',
#  'PROGESTERONE 50MG INJECTABLE INJECTION',
#  'METHYLPREDNISOLONE SODIUM SUCCINATE 125MG INJECTABLE INJECTION',
#  'OXTRIPHYLLINE 400MG TABLET EXTENDED RELEASE ORAL',
#  'TECHNETIUM TC-99M SULFUR COLLOID 4mCi/ML SOLUTION INJECTION ORAL',
#  'GUANETHIDINE MONOSULFATE 25MG TABLET ORAL',
#  'LOPINAVIR  RITONAVIR 80MG 20MG SOLUTION ORAL',
#  'AMINOSALICYLIC ACID RESIN COMPLEX 500MG POWDER ORAL',
#  'INSULIN GLARGINE RECOMBINANT 100 UNITS/ML INJECTABLE INJECTION',
#  "ALPHA-TOCOPHEROL ACETATE  ASCORBIC ACID  BIOTIN  CHOLECALCIFEROL  CYANOCOBALAMIN  DEXPANTHENOL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE HYDROCHLORIDE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE HYDROCHLORIDE  VITAMIN A PALMITATE  VITAMIN K 40MG 3MG 120 8MG 1.2MG 0.72MG 1.2MG 660 0.03MG INJECTABLE IV INFUSION",
#  'PHENPROCOUMON 3MG TABLET ORAL',
#  'TRIPTORELIN PAMOATE 2.5MG FOR SUSPENSION EXTENDED RELEASE INTRAMUSCULAR',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 450MG 100ML INJECTABLE INJECTION',
#  'LEVALBUTEROL HYDROCHLORIDE 0.2 5% SOLUTION INHALATION',
#  'ROFECOXIB 2.5MG 5ML SUSPENSION ORAL',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE  TRIPROLIDINE HYDROCHLORIDE 30MG 5ML 1.25MG 5ML SYRUP ORAL',
#  'UROKINASE 90 INJECTABLE INJECTION',
#  'AMINO ACIDS 150GM/1000ML INJECTABLE INJECTION',
#  'IDARUBICIN HYDROCHLORIDE 1MG INJECTABLE INJECTION',
#  'CIMETIDINE HYDROCHLORIDE 90MG 100ML INJECTABLE INJECTION',
#  'CHLORPROTHIXENE 10MG TABLET ORAL',
#  'MEPROBAMATE 600MG TABLET ORAL',
#  'DONEPEZIL HYDROCHLORIDE 5MG 5ML SOLUTION ORAL',
#  'SPIRAPRIL HYDROCHLORIDE 3MG TABLET ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 4.25GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'LIXISENATIDE 0.1MG/ML SOLUTION SUBCUTANEOUS',
#  'PYRVINIUM PAMOATE 50MG 5ML SUSPENSION ORAL',
#  'INSULIN SUSP ISOPHANE PURIFIED PORK 100 INJECTABLE INJECTION',
#  'LEVODOPA 250MG CAPSULE ORAL',
#  'DOXORUBICIN HYDROCHLORIDE 2MG INJECTABLE INJECTION',
#  'KETOROLAC TROMETHAMINE 15MG INJECTABLE INJECTION',
#  'TRETINOIN 0.0 8% CREAM TOPICAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 110MG 100ML 200MG 100ML INJECTABLE INJECTION',
#  'FENTANYL CITRATE 0.1MG TABLET BUCCAL SUBLINGUAL',
#  'CLOBETASOL PROPIONATE 0.0 5% OINTMENT TOPICAL',
#  'NISOLDIPINE 5.5MG TABLET EXTENDED RELEASE ORAL',
#  'GALLIUM NITRATE 25MG INJECTABLE INJECTION',
#  'CHLORAMPHENICOL  PREDNISOLONE 1% 0.5 OINTMENT OPHTHALMIC',
#  'GENTAMICIN SULFATE 0.8MG INJECTABLE INJECTION',
#  'HOMATROPINE METHYLBROMIDE 3MG TABLET CHEWABLE ORAL',
#  'ROTIGOTINE 8MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CHOLESTYRAMINE 4GM BAR CHEWABLE ORAL',
#  'CEFAZOLIN SODIUM 1GM INJECTABLE INJECTION',
#  'ESTROGENS CONJUGATED  MEDROXYPROGESTERONE ACETATE 0.625MG 0.625MG 2.5MG 2.5MG TABLET ORAL-28',
#  'CEPHRADINE 250MG INJECTABLE INJECTION',
#  'SODIUM IODIDE I-131 2-2 CAPSULE ORAL',
#  'EPINEPHRINE BITARTRATE  ETIDOCAINE HYDROCHLORIDE 0.005MG 1.5 INJECTABLE INJECTION',
#  'RESERPINE 1MG TABLET ORAL',
#  'GONADORELIN HYDROCHLORIDE 0.1MG INJECTABLE INJECTION',
#  'SODIUM IODIDE I-131 1-5 0.5ML SOLUTION ORAL',
#  'INDOCYANINE GREEN 25MG INJECTABLE INJECTION',
#  'MESORIDAZINE BESYLATE 25MG CONCENTRATE ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.05MG 1MG TABLET ORAL-21',
#  'ICODEXTRIN 7.5GM 100ML SOLUTION INTRAPERITONEAL',
#  'FENTANYL CITRATE 0.4MG TROCHE/LOZENGE ORAL',
#  'AMIODARONE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'INSULIN GLARGINE RECOMBINANT 300 UNITS/ML SOLUTION SUBCUTANEOUS',
#  'POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE 420GM 1.48GM 5.72GM 1.2GM FOR SOLUTION ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.05MG 1MG TABLET ORAL-28',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 2.5MG 2.5MG 2.5MG 2.5MG TABLET ORAL',
#  'DOPAMINE HYDROCHLORIDE 160MG 100ML INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 37MG 100ML 200MG 100ML INJECTABLE INJECTION',
#  'ZILEUTON 300MG TABLET ORAL',
#  'CLADRIBINE 1MG INJECTABLE INJECTION',
#  'LEVOTHYROXINE SODIUM 0.137MG 1.8 TABLET ORAL',
#  'TETRACYCLINE HYDROCHLORIDE 500MG INJECTABLE INJECTION',
#  'DEXTROSE 500MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 10GM 100ML 110MG 100ML 450MG 100ML INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.088MG POWDER INHALATION',
#  'SODIUM BENZOATE  SODIUM PHENYLACETATE 100MG 100MG SOLUTION ORAL',
#  'TROLAMINE POLYPEPTIDE OLEATE CONDENSATE 10% SOLUTION/DROPS OTIC',
#  'LINACLOTIDE 290 CAPSULE ORAL',
#  'CLAVULANATE POTASSIUM  TICARCILLIN DISODIUM 100MG 3GM INJECTABLE INJECTION',
#  'TRETINOIN 0.0 2% CREAM TOPICAL',
#  'CEFONICID SODIUM 2GM INJECTABLE INJECTION',
#  'TIROFIBAN HYDROCHLORIDE EQ 0.25MG BASE/ML INJECTABLE INJECTION',
#  'OFLOXACIN 20MG INJECTABLE INJECTION',
#  'SODIUM IODIDE I-131 5-1 CAPSULE ORAL',
#  'HISTRELIN ACETATE 0.2MG INJECTABLE INJECTION',
#  'SECOBARBITAL SODIUM 60MG SUPPOSITORY RECTAL',
#  'ESTROGENS CONJUGATED  MEDROXYPROGESTERONE ACETATE 0.625MG 0.625MG 5MG TABLET ORAL-28',
#  'INULIN 100MG INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE 75MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'BETAXOLOL HYDROCHLORIDE 0.2 5% SUSPENSION/DROPS OPHTHALMIC',
#  'ETHYLESTRENOL 2MG 5ML ELIXIR ORAL',
#  'CALCIUM GLUCEPTATE 90MG 5ML INJECTABLE INJECTION',
#  'HYDROCORTISONE PROBUTATE 0.1 0% CREAM TOPICAL',
#  'CILASTATIN SODIUM  IMIPENEM 750MG 750MG POWDER INTRAMUSCULAR',
#  'TRETINOIN 0.1 0% GEL TOPICAL',
#  'FERRIC PYROPHOSPHATE CITRATE 5.44MG IRON/ML SOLUTION IV INFUSION',
#  'BENDAMUSTINE HYDROCHLORIDE 25MG/ML SOLUTION IV INFUSION',
#  'ETELCALCETIDE 2.5MG/0.5ML SOLUTION INTRAVENOUS',
#  'IOHEXOL 5.5 0% SOLUTION INJECTION ORAL',
#  'HYDROMORPHONE HYDROCHLORIDE 250MG INJECTABLE INJECTION',
#  'AMPHETAMINE RESIN COMPLEX  DEXTROAMPHETAMINE RESIN COMPLEX 3.75MG 3.75MG CAPSULE EXTENDED RELEASE ORAL',
#  'TERBUTALINE SULFATE 1MG INJECTABLE INJECTION',
#  'CLINDAMYCIN PHOSPHATE 1% AEROSOL FOAM TOPICAL',
#  'TICLOPIDINE HYDROCHLORIDE 125MG TABLET ORAL',
#  'PROTIRELIN 0.5MG INJECTABLE INJECTION',
#  'LEVOBUPIVACAINE HYDROCHLORIDE 7.5MG INJECTABLE INJECTION',
#  'AMINOCAPROIC ACID 1.25GM 5ML SYRUP ORAL',
#  'SULFADIAZINE 300MG TABLET ORAL',
#  'ISOSORBIDE 100GM 220ML SOLUTION ORAL',
#  'SODIUM NITROPRUSSIDE 0.5MG/ML SOLUTION IV INFUSION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.3MG 100ML 3.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'NALDEMEDINE TOSYLATE 0.2MG TABLET ORAL',
#  'GLYBURIDE 2.5 TABLET ORAL',
#  'HYDROCORTISONE  NEOMYCIN SULFATE 0.5 3.5MG CREAM TOPICAL',
#  'AMINO ACIDS  DEXTROSE 2.7 5% 20GM 100ML INJECTABLE INJECTION',
#  'FLUDEOXYGLUCOSE F-18 4-4 INJECTABLE INJECTION',
#  'CETRORELIX 3MG INJECTABLE INJECTION',
#  'METRONIDAZOLE 1.3 0% GEL VAGINAL',
#  'PREDNISOLONE TEBUTATE 20MG INJECTABLE INJECTION',
#  'LIDOCAINE HYDROCHLORIDE 0.5MG SYSTEM INTRADERMAL',
#  'AZILSARTAN KAMEDOXOMIL  CHLORTHALIDONE 40MG 2.5MG TABLET ORAL',
#  'HYDROCORTISONE ACETATE 10% AEROSOL METERED RECTAL',
#  'AMINO ACIDS 5.2GM/100ML INJECTABLE INJECTION',
#  'LIOTRIX T4 T3 0.12MG 0.03MG TABLET ORAL',
#  'ASPIRIN  PRAVASTATIN SODIUM 81MG 40MG TABLET TABLET TABLET ORAL',
#  'HYDROCORTISONE ACETATE 0.5 0% LOTION TOPICAL',
#  ...}

# %% [markdown]
# ## With levels

# %%
RxCUI_levels_file = pd.read_csv("../../rxcui/RxCUI_levels.csv")

# %%
missingRxCUI = pd.isnull(RxCUI_levels_file.RxCUI)
queries_missing = RxCUI_levels_file.ix[missingRxCUI].Query_ISD
#Extract unique values
queries_missing = set(queries_missing)

# %%
len(queries_missing)
# Out:
# 2095

# %%
queries_missing
# Out:
# {'AZTREONAM 500MG INJECTABLE INJECTION',
#  'SAFFLOWER OIL  SOYBEAN OIL 5GM/100ML INJECTABLE INJECTION',
#  'PIPERACILLIN SODIUM  TAZOBACTAM SODIUM 36GM 4.5GM INJECTABLE INJECTION',
#  'PREDNISOLONE SODIUM PHOSPHATE  SULFACETAMIDE SODIUM 0.2 3% 10% SOLUTION/DROPS OPHTHALMIC',
#  'ERYTHROMYCIN 0.5 0% OINTMENT OPHTHALMIC',
#  'AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE  VALSARTAN 5MG 2.5MG 160MG TABLET ORAL',
#  'DAPTOMYCIN 500MG POWDER INTRAVENOUS',
#  'ESTRADIOL 0.06MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.3MG 100ML 2.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'FENTANYL CITRATE 0.8MG TABLET BUCCAL SUBLINGUAL',
#  'SODIUM MONOFLUOROPHOSPHATE 1.2 0% PASTE DENTAL',
#  'FONDAPARINUX SODIUM 2.5MG 0.5ML INJECTABLE SUBCUTANEOUS',
#  'IPRATROPIUM BROMIDE 0.0 2% SOLUTION INHALATION',
#  'HETACILLIN 112 5MG FOR SUSPENSION ORAL',
#  'FOLLITROPIN ALFA/BETA 7.5 INJECTABLE SUBCUTANEOUS',
#  'DIETHYLSTILBESTROL 0.1MG SUPPOSITORY VAGINAL',
#  'CEFTIZOXIME SODIUM 40MG INJECTABLE INJECTION',
#  'MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM GLUCONATE 30MG 100ML 37MG 100ML 222MG 100ML 526MG 100ML 502MG 100ML SOLUTION IRRIGATION',
#  'CLOFARABINE 1MG/ML INJECTABLE IV INFUSION',
#  'DROSPIRENONE  ETHINYL ESTRADIOL 3MG 0.03MG TABLET ORAL-28',
#  'NANDROLONE DECANOATE 200MG INJECTABLE INJECTION',
#  'BUDESONIDE  FORMOTEROL FUMARATE DIHYDRATE 0.16MG 0.0045MG AEROSOL METERED INHALATION',
#  'PENICILLIN G POTASSIUM 00 TABLET ORAL',
#  'VERAPAMIL HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'HYDROCORTISONE 0.5 0% OINTMENT TOPICAL',
#  'AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE  OLMESARTAN MEDOXOMIL 5MG 2.5MG 20MG TABLET ORAL',
#  'CYTARABINE 2GM INJECTABLE INJECTION',
#  'FUROSEMIDE 10MG SOLUTION ORAL',
#  'CIMETIDINE HYDROCHLORIDE 300MG 2ML INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  TRIAMTERENE 25MG 7.5MG CAPSULE ORAL',
#  'PHENTERMINE HYDROCHLORIDE 7.5MG TABLET ORAL',
#  'ACETIC ACID GLACIAL 250MG 100ML SOLUTION IRRIGATION URETHRAL',
#  'DIATRIZOATE MEGLUMINE 30% SOLUTION URETHRAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 1MG TABLET ORAL-21',
#  'POTASSIUM AMINOSALICYLATE 1GM TABLET ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 1MG TABLET ORAL-28',
#  'OCTREOTIDE ACETATE 0.2MG INJECTABLE INJECTION',
#  'HYDROMORPHONE HYDROCHLORIDE 2MG INJECTABLE INJECTION',
#  'INSULIN SUSP PROTAMINE ZINC PURIFIED BEEF 100 INJECTABLE INJECTION',
#  'BISACODYL  POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE 5MG 210GM 0.74GM 2.86GM 5.6GM FOR SOLUTION TABLET DELAYED RELEASE ORAL',
#  'DOXEPIN HYDROCHLORIDE 10MG CONCENTRATE ORAL',
#  'MOMETASONE FUROATE 0.1 0% LOTION TOPICAL',
#  'ALFENTANIL HYDROCHLORIDE 0.5MG INJECTABLE INJECTION',
#  'PAMIDRONATE DISODIUM 60MG INJECTABLE INJECTION',
#  'DEXTROSE 60GM 100ML INJECTABLE INJECTION',
#  'ESMOLOL HYDROCHLORIDE 10MG INJECTABLE INJECTION',
#  'CYANOCOBALAMIN 0.5MG SPRAY METERED NASAL',
#  'VECURONIUM BROMIDE 20MG INJECTABLE INJECTION',
#  'TRANEXAMIC ACID 100MG INJECTABLE INJECTION',
#  'PHENYLEPHRINE HYDROCHLORIDE 10MG/ML SOLUTION IV INFUSION',
#  'FLUOCINONIDE 0.0 5% CREAM TOPICAL',
#  'CLOZAPINE 150MG TABLET ORALLY DISINTEGRATING ORAL',
#  'ISOPROTERENOL HYDROCHLORIDE 0.12MG AEROSOL METERED INHALATION',
#  'CISPLATIN 10MG INJECTABLE INJECTION',
#  'DIAZEPAM 5MG INJECTABLE INJECTION',
#  'DAUNORUBICIN HYDROCHLORIDE 5MG INJECTABLE INJECTION',
#  'IDARUBICIN HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'DEXAMETHASONE SODIUM PHOSPHATE 0.1 SOLUTION/DROPS OTIC',
#  'AMPICILLIN/AMPICILLIN TRIHYDRATE 500MG CAPSULE ORAL',
#  'CALCIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 33MG 100ML 30MG 100ML 860MG 100ML INJECTABLE INJECTION',
#  'BACLOFEN 0.5MG INJECTABLE INTRATHECAL',
#  'TRIMETHOBENZAMIDE HYDROCHLORIDE 100MG INJECTABLE INJECTION',
#  'TERBUTALINE SULFATE 0.2MG AEROSOL METERED INHALATION',
#  'NITROGLYCERIN 10MG 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 2.7 5% 25GM 100ML 51MG 100ML 261MG 100ML 216MG 100ML 112MG 100ML INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  TELMISARTAN 2.5MG 40MG TABLET ORAL',
#  'BUPIVACAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 0.2 5% 0.0091MG INJECTABLE INJECTION',
#  'KETOROLAC TROMETHAMINE 0.4 0% SOLUTION/DROPS OPHTHALMIC',
#  'LEVODOPA 100MG CAPSULE ORAL',
#  'CEFORANIDE 20GM INJECTABLE INJECTION',
#  'DIATRIZOATE SODIUM 50% INJECTABLE INJECTION',
#  'CEFTIZOXIME SODIUM 1GM INJECTABLE INJECTION',
#  'METFORMIN HYDROCHLORIDE  ROSIGLITAZONE MALEATE 1GM 2MG TABLET ORAL',
#  'MEROPENEM 500MG INJECTABLE INJECTION',
#  'BECLOMETHASONE DIPROPIONATE 0.042MG AEROSOL METERED INHALATION',
#  'INSULIN SUSP ISOPHANE BEEF/PORK 40 UNITS/ML INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 1MG TABLET ORAL-21',
#  'NYSTATIN  TRIAMCINOLONE ACETONIDE 100 000 0.1 OINTMENT TOPICAL',
#  'DIAZOXIDE 15MG INJECTABLE INJECTION',
#  'HYDROCORTISONE 100% POWDER FOR RX COMPOUNDING',
#  'DEXTROSE  POTASSIUM CHLORIDE 5GM 100ML 75MG 100ML INJECTABLE INJECTION',
#  'HYDROFLUMETHIAZIDE  RESERPINE 50MG 0.125MG TABLET ORAL',
#  'AVOBENZONE  ECAMSULE  OCTOCRYLENE  TITANIUM DIOXIDE 2% 3% 10% 5% CREAM TOPICAL',
#  'CLOBETASOL PROPIONATE 0.0 5% SHAMPOO TOPICAL',
#  'ESTRADIOL CYPIONATE  TESTOSTERONE CYPIONATE 2MG 50MG INJECTABLE INJECTION',
#  'RIVASTIGMINE 9.5MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'EXENATIDE SYNTHETIC 250MCG/ML INJECTABLE SUBCUTANEOUS',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.035MG 0.035MG 0.18MG 0.215MG 0.25MG TABLET ORAL-21',
#  'IFOSFAMIDE 1GM INJECTABLE INJECTION',
#  'AMIKACIN SULFATE 50MG INJECTABLE INJECTION',
#  'BROMODIPHENHYDRAMINE HYDROCHLORIDE  CODEINE PHOSPHATE 2.5MG 5ML 10MG 5ML SYRUP ORAL',
#  'AMPICILLIN SODIUM 250MG INJECTABLE INJECTION',
#  'MORPHINE SULFATE 1MG INJECTABLE INJECTION',
#  'METHDILAZINE HYDROCHLORIDE 4MG 5ML SYRUP ORAL',
#  'DIHYDROERGOTAMINE MESYLATE  HEPARIN SODIUM  LIDOCAINE HYDROCHLORIDE 0.5MG 0.7ML 50 0.7ML 7.46MG 0.7ML INJECTABLE INJECTION',
#  'DIPHENHYDRAMINE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'TRIPLE SULFA SULFABENZAMIDE SULFACETAMIDE SULFATHIAZOLE 3.7 2.8 6% 3.4 2% CREAM VAGINAL',
#  'CARBENICILLIN DISODIUM 1GM INJECTABLE INJECTION',
#  'TRIPROLIDINE HYDROCHLORIDE 1.25MG 5ML SYRUP ORAL',
#  'PENTOBARBITAL SODIUM 50MG INJECTABLE INJECTION',
#  'OFLOXACIN 40MG INJECTABLE INJECTION',
#  'OCTREOTIDE ACETATE 1MG INJECTABLE INJECTION',
#  'FLUORESCEIN SODIUM EQ 100MG BASE/ML INJECTABLE INTRAVENOUS',
#  'RESERPINE  TRICHLORMETHIAZIDE 0.1MG 4MG TABLET ORAL',
#  'OXACILLIN SODIUM 2GM POWDER INTRAVENOUS',
#  'FLUOCINOLONE ACETONIDE 0.0 1% OIL TOPICAL',
#  'ETHACRYNATE SODIUM 50MG INJECTABLE INJECTION',
#  'SODIUM POLYSTYRENE SULFONATE 15GM POWDER ORAL RECTAL',
#  'GRISEOFULVIN ULTRAMICROCRYSTALLINE 165MG TABLET ORAL',
#  'LIDOCAINE HYDROCHLORIDE 800MG 100ML INJECTABLE INJECTION',
#  'IBUPROFEN LYSINE EQ 10MG BASE/ML INJECTABLE INTRAVENOUS',
#  'FLUDEOXYGLUCOSE F-18 0-5 INJECTABLE INTRAVENOUS',
#  'PROCHLORPERAZINE EDISYLATE 5MG INJECTABLE INJECTION',
#  'IBANDRONATE SODIUM 3MG 3ML INJECTABLE INTRAVENOUS',
#  'BETAMETHASONE DIPROPIONATE  CALCIPOTRIENE HYDRATE 0.0 64% 0.0 05% OINTMENT TOPICAL',
#  'CLOBETASOL PROPIONATE 0.0 5% GEL TOPICAL',
#  'LEUCOVORIN CALCIUM 350MG INJECTABLE INJECTION',
#  'TRISULFAPYRIMIDINES SULFADIAZINE SULFAMERAZINE SULFAMETHAZINE 167MG 5ML 167MG 5ML 167MG 5ML SUSPENSION ORAL',
#  'DIPYRIDAMOLE 5MG INJECTABLE INJECTION',
#  'CIPROFLOXACIN 200MG 100ML INJECTABLE INJECTION',
#  'PANTOPRAZOLE SODIUM 40MG INJECTABLE IV INFUSION',
#  'BACITRACIN ZINC  HYDROCORTISONE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 400 1% 3.5MG 50 OINTMENT TOPICAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 75MG 100ML 330MG 100ML INJECTABLE INJECTION',
#  'CEFTAZIDIME SODIUM 20MG INJECTABLE INJECTION',
#  'METHYLDOPATE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'BENZTROPINE MESYLATE 1MG INJECTABLE INJECTION',
#  'NEOMYCIN SULFATE  POLYMYXIN B SULFATE 40MG 200 000 SOLUTION IRRIGATION',
#  'STERILE WATER FOR INJECTION 100% LIQUID N/A',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.01MG 2% SOLUTION IONTOPHORESIS TOPICAL',
#  'TESTOSTERONE ENANTHATE 200MG INJECTABLE INJECTION',
#  'DOBUTAMINE HYDROCHLORIDE 400MG 100ML INJECTABLE INJECTION',
#  "ASCORBIC ACID  BIOTIN  CYANOCOBALAMIN  DEXPANTHENOL  ERGOCALCIFEROL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE HYDROCHLORIDE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE HYDROCHLORIDE  VITAMIN A  VITAMIN E 20MG 0.006MG 0.0 1.5MG 0.0005MG 0.06MG 4MG 0.6MG 0.36MG 0.6MG 0.1MG 1MG INJECTABLE INJECTION",
#  'PENICILLIN G POTASSIUM 00 00 INJECTABLE INJECTION',
#  'ARTICAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 4% EQ 0.01MG BASE/ML INJECTABLE INJECTION',
#  'TOPOTECAN HYDROCHLORIDE 4MG INJECTABLE INJECTION',
#  'SODIUM CHLORIDE 900MG 100ML SOLUTION IRRIGATION',
#  'ESTROPIPATE 6MG TABLET ORAL',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 4.2 5% 6.8MG 100ML 25GM 100ML 51MG 100ML 2.4MG 100ML 261MG 100ML 205MG 100ML INJECTABLE INJECTION',
#  'METHOCARBAMOL 100MG INJECTABLE INJECTION',
#  'CALCIUM GLUCONATE 100MG/ML SOLUTION IV INFUSION',
#  'CASPOFUNGIN ACETATE 50MG POWDER IV INFUSION',
#  'CLOFIBRATE 500MG CAPSULE ORAL',
#  'PENICILLIN V POTASSIUM 125MG TABLET ORAL',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 900MG 100ML INJECTABLE INJECTION',
#  'FLOXURIDINE 500MG INJECTABLE INJECTION',
#  'LEVOLEUCOVORIN CALCIUM EQ 10MG BASE/ML SOLUTION IV INFUSION',
#  'ERYTHROMYCIN ETHYLSUCCINATE  SULFISOXAZOLE ACETYL 200MG 5ML 600MG 5ML GRANULE ORAL',
#  'OXYTOCIN 100ML INJECTABLE INJECTION',
#  'FLUOROMETHOLONE 0.1 0% SUSPENSION/DROPS OPHTHALMIC',
#  'HEPARIN SODIUM 10 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS 10GM/100ML INJECTABLE INJECTION',
#  'METHYLTESTOSTERONE 5MG TABLET BUCCAL SUBLINGUAL',
#  'ETHINYL ESTRADIOL  ETHYNODIOL DIACETATE 0.035MG 1MG TABLET ORAL-28',
#  'SULFISOXAZOLE DIOLAMINE 4% SOLUTION/DROPS OPHTHALMIC',
#  'ETHINYL ESTRADIOL  ETHYNODIOL DIACETATE 0.035MG 1MG TABLET ORAL-21',
#  'FLUMAZENIL 0.1MG/ML INJECTABLE INJECTION',
#  'THIAMINE HYDROCHLORIDE 200MG INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M MEDRONATE nan INJECTABLE INJECTION',
#  'LEUCOVORIN CALCIUM 50MG INJECTABLE INJECTION',
#  'MEPIVACAINE HYDROCHLORIDE 1.5 0% INJECTABLE INJECTION',
#  'ACETAMINOPHEN  ASPIRIN  CODEINE PHOSPHATE 150MG 180MG 15MG CAPSULE ORAL',
#  'SODIUM BENZOATE  SODIUM PHENYLACETATE 5GM/50ML 5GM/50ML SOLUTION IV INFUSION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 0.035MG 0.035MG 0.5MG 1MG 0.5MG TABLET ORAL-28',
#  'MIVACURIUM CHLORIDE EQ 2MG BASE/ML SOLUTION INTRAVENOUS',
#  'AMIKACIN SULFATE 250MG INJECTABLE INJECTION',
#  'SECOBARBITAL SODIUM 50MG INJECTABLE INJECTION',
#  'DIATRIZOATE MEGLUMINE 30% INJECTABLE INJECTION',
#  'METAPROTERENOL SULFATE 0.6 0% SOLUTION INHALATION',
#  'FLUDEOXYGLUCOSE F-18 0-3 INJECTABLE INTRAVENOUS',
#  'NAPROXEN SODIUM 500MG TABLET ORAL',
#  'CANAGLIFLOZIN  METFORMIN HYDROCHLORIDE 50MG 1GM TABLET ORAL',
#  'METOPROLOL TARTRATE 1MG INJECTABLE INJECTION',
#  'DIAZEPAM 5MG/ML GEL RECTAL',
#  'FENTANYL CITRATE 0.8MG TROCHE/LOZENGE TRANSMUCOSAL',
#  'DEXTROSE  POTASSIUM CHLORIDE 5GM 100ML 300MG 100ML INJECTABLE INJECTION',
#  'FLUPHENAZINE HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'PENICILLIN G BENZATHINE 300 000 INJECTABLE INJECTION',
#  'EPINEPHRINE 0.3MG INJECTABLE INTRAMUSCULAR SUBCUTANEOUS',
#  'HYDROCORTISONE VALERATE 0.2 0% OINTMENT TOPICAL',
#  'THEOPHYLLINE 160MG 100ML INJECTABLE INJECTION',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 3.75MG 3.75MG 3.75MG 3.75MG CAPSULE ORAL',
#  'FAMOTIDINE 10MG TABLET CHEWABLE ORAL',
#  'DESOXIMETASONE 0.0 5% CREAM TOPICAL',
#  'SODIUM POLYSTYRENE SULFONATE 15GM 60ML SUSPENSION ORAL RECTAL',
#  'CLINDAMYCIN PHOSPHATE 6MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 0.035MG 0.035MG 0.5MG 0.75MG 1MG TABLET ORAL-28',
#  'FLUOCINONIDE 0.0 5% SOLUTION TOPICAL',
#  'GADOTERIDOL 279 3MG INJECTABLE INJECTION',
#  'VANCOMYCIN HYDROCHLORIDE 10GM INJECTABLE INJECTION',
#  'ISONIAZID 100MG INJECTABLE INJECTION',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 1.25MG 1.25MG 1.25MG 1.25MG TABLET ORAL',
#  'MEDROXYPROGESTERONE ACETATE 150MG INJECTABLE INJECTION',
#  'CLORAZEPATE DIPOTASSIUM 3.75MG CAPSULE ORAL',
#  'IBUPROFEN 300MG TABLET ORAL',
#  'ARGATROBAN 1MG/ML INJECTABLE IV INFUSION',
#  'HEXACHLOROPHENE 480MG SPONGE TOPICAL',
#  'CITALOPRAM HYDROBROMIDE 10MG TABLET ORALLY DISINTEGRATING ORAL',
#  'ETHINYL ESTRADIOL  FERROUS FUMARATE  NORETHINDRONE ACETATE 0.05MG 75MG 2.5MG TABLET ORAL-28',
#  'FUROSEMIDE 10MG INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 5.8MG INJECTABLE INJECTION',
#  'PREDNISOLONE SODIUM PHOSPHATE 0.9 SOLUTION/DROPS OPHTHALMIC',
#  'ETHCHLORVYNOL 100MG CAPSULE ORAL',
#  'PENICILLIN G SODIUM 50 00 INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  LABETALOL HYDROCHLORIDE 25MG 400MG TABLET ORAL',
#  'MYCOPHENOLATE MOFETIL HYDROCHLORIDE 500MG INJECTABLE INJECTION',
#  'CEPHAPIRIN SODIUM 2GM INJECTABLE INJECTION',
#  'MYCOPHENOLATE MOFETIL 200MG SUSPENSION ORAL',
#  'ONDANSETRON HYDROCHLORIDE 2MG INJECTABLE INJECTION',
#  'ADAPALENE 0.1 0% CREAM TOPICAL',
#  'ERYTHROMYCIN 1.5 0% SOLUTION TOPICAL',
#  'TRIAMCINOLONE 8MG TABLET ORAL',
#  'POTASSIUM CHLORIDE 1.49GM 100ML INJECTABLE INJECTION',
#  'DIATRIZOATE MEGLUMINE  DIATRIZOATE SODIUM 52% 8% INJECTABLE INJECTION',
#  'INSULIN ASPART PROTAMINE RECOMBINANT  INSULIN ASPART RECOMBINANT 50 UNITS/ML 50 UNITS/ML INJECTABLE SUBCUTANEOUS',
#  'AMINO ACIDS 8.5GM/100ML INJECTABLE INJECTION',
#  'METHAMPHETAMINE HYDROCHLORIDE 10MG TABLET ORAL',
#  'THEOPHYLLINE 40MG 100ML INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.05MG SPRAY METERED NASAL',
#  'DOXERCALCIFEROL 0.5 CAPSULE ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 4.5MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'AMPICILLIN/AMPICILLIN TRIHYDRATE 250MG CAPSULE ORAL',
#  'TECHNETIUM TC-99M ALBUMIN AGGREGATED KIT nan INJECTABLE INJECTION',
#  'HYDROCORTISONE SODIUM SUCCINATE 100MG INJECTABLE INJECTION',
#  'CLINDAMYCIN PHOSPHATE 900MG 100ML INJECTABLE INJECTION',
#  'DESOXIMETASONE 0.0 5% OINTMENT TOPICAL',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE 220MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'HEPARIN SODIUM 100 INJECTABLE INJECTION',
#  'DESOXIMETASONE 0.0 5% GEL TOPICAL',
#  'AMOXICILLIN  CLAVULANATE POTASSIUM 200MG 8.5MG TABLET CHEWABLE ORAL',
#  'DICLOFENAC SODIUM 0.1 0% SOLUTION/DROPS OPHTHALMIC',
#  'IDARUBICIN HYDROCHLORIDE 10MG INJECTABLE INJECTION',
#  'MICONAZOLE NITRATE 2% 1.2GM CREAM SUPPOSITORY TOPICAL VAGINAL',
#  'HYDROCHLOROTHIAZIDE  MOEXIPRIL HYDROCHLORIDE 2.5MG 7.5MG TABLET ORAL',
#  'LEUPROLIDE ACETATE 45MG INJECTABLE SUBCUTANEOUS',
#  'IOHEXOL 1.8 0% SOLUTION INJECTION ORAL RECTAL',
#  'GONADOTROPIN CHORIONIC 20 INJECTABLE INJECTION',
#  'LEVOCARNITINE 200MG INJECTABLE INJECTION',
#  'FLUOXETINE HYDROCHLORIDE 90MG CAPSULE DELAYED REL PELLETS ORAL',
#  'BETAMETHASONE BENZOATE 0.0 3% GEL TOPICAL',
#  'DOXYCYCLINE HYCLATE 100MG INJECTABLE INJECTION',
#  'NICARDIPINE HYDROCHLORIDE 2.5MG/ML INJECTABLE INJECTION',
#  'OXYMETAZOLINE HYDROCHLORIDE 0.0 3% SOLUTION/DROPS OPHTHALMIC',
#  'TACROLIMUS 0.1 0% OINTMENT TOPICAL',
#  'FENTANYL CITRATE 1.6MG TROCHE/LOZENGE TRANSMUCOSAL',
#  'DEXTROSE 20GM 100ML INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 10MG/ML INJECTABLE INJECTION',
#  'AZITHROMYCIN 500MG INJECTABLE INJECTION',
#  'AMINOPHYLLINE 100MG 100ML INJECTABLE INJECTION',
#  'ESTRADIOL VALERATE 10MG INJECTABLE INJECTION',
#  'CEFADROXIL/CEFADROXIL HEMIHYDRATE 125MG 5ML FOR SUSPENSION ORAL',
#  'MORPHINE SULFATE 0.5MG INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  QUINAPRIL HYDROCHLORIDE 2.5MG 10MG TABLET ORAL',
#  'MIDAZOLAM HYDROCHLORIDE 2MG SYRUP ORAL',
#  'UROFOLLITROPIN 150 INJECTABLE SUBCUTANEOUS',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 0.03MG 0.035MG 1MG 1MG 1MG TABLET ORAL-28',
#  'CEFAZOLIN SODIUM 20MG INJECTABLE INJECTION',
#  'BUTORPHANOL TARTRATE 2MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.02MG 0.03MG 0.035MG 1MG 1MG 1MG TABLET ORAL-21',
#  'HYDRALAZINE HYDROCHLORIDE  RESERPINE 25MG 0.1MG TABLET ORAL',
#  'MEPIVACAINE HYDROCHLORIDE 2% INJECTABLE INJECTION',
#  'METOCLOPRAMIDE HYDROCHLORIDE 5MG TABLET ORALLY DISINTEGRATING ORAL',
#  'AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE  OLMESARTAN MEDOXOMIL 10MG 2.5MG 40MG TABLET ORAL',
#  'OXACILLIN SODIUM 250MG 5ML FOR SOLUTION ORAL',
#  'ISOETHARINE MESYLATE 0.34MG AEROSOL METERED INHALATION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 4.2 5% 33MG 100ML 5GM 100ML 51MG 100ML 261MG 100ML 297MG 100ML 77MG 100ML INJECTABLE INJECTION',
#  'CYCLOPHOSPHAMIDE 1GM INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.11MG AEROSOL METERED INHALATION',
#  'CEFAMANDOLE NAFATE 1GM INJECTABLE INJECTION',
#  'BETAMETHASONE BENZOATE 0.0 3% LOTION TOPICAL',
#  'THEOPHYLLINE 4MG INJECTABLE INJECTION',
#  'TORSEMIDE 10MG/ML INJECTABLE INJECTION',
#  'DEXTROMETHORPHAN HYDROBROMIDE  GUAIFENESIN 60MG 1.2GM TABLET EXTENDED RELEASE ORAL',
#  'PROMAZINE HYDROCHLORIDE 100MG TABLET ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 3.5GM 100ML 5.2MG 100ML 567MG 100ML 392MG 100ML SOLUTION INTRAPERITONEAL',
#  'ROCURONIUM BROMIDE 10MG/ML INJECTABLE INJECTION',
#  'HYDROCORTISONE BUTYRATE 0.1 0% CREAM TOPICAL',
#  'FOLIC ACID 5MG INJECTABLE INJECTION',
#  'TESTOSTERONE CYPIONATE 200MG INJECTABLE INJECTION',
#  'NAFCILLIN SODIUM 2GM INJECTABLE INJECTION',
#  'LIDOCAINE HYDROCHLORIDE 1.5 0% INJECTABLE SPINAL',
#  'METHICILLIN SODIUM 3.6GM INJECTABLE INJECTION',
#  'PREDNISOLONE SODIUM PHOSPHATE 15MG TABLET ORALLY DISINTEGRATING ORAL',
#  'ASPIRIN  PRAVASTATIN SODIUM 325MG 80MG TABLET TABLET ORAL',
#  'OFLOXACIN 0.3 0% SOLUTION/DROPS OTIC',
#  'CEPHAPIRIN SODIUM 500MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 300MG 100ML 200MG 100ML INJECTABLE INJECTION',
#  'NYSTATIN 100 000 OINTMENT TOPICAL',
#  'CYCLACILLIN 500MG TABLET ORAL',
#  'XYLOSE 25GM POWDER ORAL',
#  'LEVOLEUCOVORIN CALCIUM 50MG POWDER IV INFUSION',
#  'HYDROCORTISONE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 1% 3.5MG 00 SUSPENSION/DROPS OPHTHALMIC',
#  'TECHNETIUM TC-99M SODIUM PERTECHNETATE GENERATOR 830 166 SOLUTION INTRAVENOUS ORAL',
#  'TRETINOIN 0.0 3% GEL TOPICAL',
#  'TRIAMCINOLONE 2MG TABLET ORAL',
#  'PROPOXYPHENE HYDROCHLORIDE 32MG CAPSULE ORAL',
#  'ACETAMINOPHEN  TRAMADOL HYDROCHLORIDE 325MG 7.5MG TABLET ORAL',
#  'NYSTATIN 100% POWDER ORAL',
#  'PENICILLIN G BENZATHINE 600 000 INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  LOSARTAN POTASSIUM 2.5MG 50MG TABLET ORAL',
#  'DIATRIZOATE MEGLUMINE  DIATRIZOATE SODIUM 66% 10% INJECTABLE INJECTION',
#  'PENICILLIN G SODIUM 50 00 INJECTABLE INTRAMUSCULAR INTRAVENOUS',
#  'HYDROCHLOROTHIAZIDE  QUINAPRIL HYDROCHLORIDE 2.5MG 20MG TABLET ORAL',
#  'PROCHLORPERAZINE EDISYLATE 5MG 5ML SYRUP ORAL',
#  'FLUDEOXYGLUCOSE F-18 4-4 INJECTABLE INTRAVENOUS',
#  'SODIUM IODIDE I-131 1-1 CAPSULE ORAL',
#  'ZOLEDRONIC ACID 4MG 100ML INJECTABLE IV INFUSION',
#  'PREDNISOLONE ACETATE 25MG INJECTABLE INJECTION',
#  'HEPARIN SODIUM 10 UNITS/ML INJECTABLE INJECTION',
#  'AMITRIPTYLINE HYDROCHLORIDE  CHLORDIAZEPOXIDE 2.5MG 5MG TABLET ORAL',
#  'DOXYCYCLINE HYCLATE 200MG INJECTABLE INJECTION',
#  'SERTRALINE HYDROCHLORIDE 20MG CONCENTRATE ORAL',
#  'AZELASTINE HYDROCHLORIDE 0.0 5% SOLUTION/DROPS OPHTHALMIC',
#  'BROMPHENIRAMINE MALEATE 10MG INJECTABLE INJECTION',
#  'INSULIN GLULISINE RECOMBINANT 100 UNITS/ML INJECTABLE IV INFUSION SUBCUTANEOUS',
#  'AMMONIA N-13 3.75-37.5mCi/ML INJECTABLE INTRAVENOUS',
#  'LEVOTHYROXINE SODIUM 0.175MG 1.8 TABLET ORAL',
#  'DEXRAZOXANE HYDROCHLORIDE 500MG INJECTABLE INJECTION',
#  'SUFENTANIL CITRATE 0.05MG INJECTABLE INJECTION',
#  'LEVALBUTEROL HYDROCHLORIDE 0.2 5% SOLUTION INHALATION',
#  'DESOXIMETASONE 0.2 5% SPRAY TOPICAL',
#  'CALCIUM CHLORIDE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM CITRATE 35MG 100ML 30MG 100ML 74MG 100ML 640MG 100ML 500MG 100ML 74MG 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 4.2 5% 33MG 100ML 20GM 100ML 51MG 100ML 261MG 100ML 297MG 100ML 77MG 100ML INJECTABLE INJECTION',
#  'CORTISONE ACETATE 25MG INJECTABLE INJECTION',
#  'CYANOCOBALAMIN 1MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.25MG TABLET ORAL-28',
#  'QUINIDINE SULFATE 200MG CAPSULE ORAL',
#  'THEOPHYLLINE 80MG 15ML SYRUP ORAL',
#  'LEUPROLIDE ACETATE 30MG INJECTABLE SUBCUTANEOUS',
#  'TRICHLORMETHIAZIDE 2MG TABLET ORAL',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM SULFATE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM GLYCEROPHOSPHATE  SOYBEAN OIL 2566ML EMULSION IV INFUSION',
#  'ESTRADIOL 0.1MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CHLORAMPHENICOL SODIUM SUCCINATE 1GM INJECTABLE INJECTION',
#  'PENICILLIN G POTASSIUM 200 000 TABLET ORAL',
#  'ZICONOTIDE ACETATE 100MCG/ML INJECTABLE INTRATHECAL',
#  'DEXRAZOXANE HYDROCHLORIDE 250MG INJECTABLE INJECTION',
#  'FLUOROURACIL 50MG INJECTABLE INJECTION',
#  'IFOSFAMIDE 50MG/ML INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 3.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'PANCURONIUM BROMIDE 1MG INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M ETIDRONATE KIT nan INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M SULFUR COLLOID KIT nan SOLUTION INJECTION ORAL',
#  'ASPIRIN  PRAVASTATIN SODIUM 325MG 40MG TABLET TABLET TABLET ORAL',
#  'DILTIAZEM HYDROCHLORIDE 100MG INJECTABLE INJECTION',
#  'HALOPERIDOL LACTATE 2MG CONCENTRATE ORAL',
#  'PHENYLEPHRINE HYDROCHLORIDE 2.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'RANITIDINE HYDROCHLORIDE 15MG SYRUP ORAL',
#  'TETRACYCLINE HYDROCHLORIDE 250MG INJECTABLE INJECTION',
#  'THEOPHYLLINE 400MG 100ML INJECTABLE INJECTION',
#  'LEVOFLOXACIN 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'ASPIRIN  CAFFEINE  PROPOXYPHENE HYDROCHLORIDE 389MG 2.4MG 65MG CAPSULE ORAL',
#  'HYDROCORTISONE BUTYRATE 0.1 0% SOLUTION TOPICAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 2.5GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'INSULIN LISPRO RECOMBINANT 100 INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE 2.24GM 100ML INJECTABLE INJECTION',
#  'IOVERSOL 68% INJECTABLE INJECTION',
#  'CEFTIZOXIME SODIUM 20MG INJECTABLE INJECTION',
#  'SODIUM BICARBONATE 1MEQ/ML INJECTABLE INJECTION',
#  "RIBOFLAVIN 5'-PHOSPHATE SODIUM 0.1 5% SOLUTION/DROPS OPHTHALMIC",
#  'METHOTREXATE SODIUM 1GM INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORETHINDRONE ACETATE 0.05MG 1MG TABLET ORAL-28',
#  'OXACILLIN SODIUM 1GM POWDER INTRAVENOUS',
#  'BECLOMETHASONE DIPROPIONATE MONOHYDRATE 0.042MG SPRAY METERED NASAL',
#  'TROPICAMIDE 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 224MG 100ML 330MG 100ML INJECTABLE INJECTION',
#  'BRETYLIUM TOSYLATE 50MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 5GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'RESERPINE 2.5MG INJECTABLE INJECTION',
#  'METHYLPREDNISOLONE ACETATE 20MG INJECTABLE INJECTION',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 450MG 100ML INJECTABLE INJECTION',
#  'ALISKIREN HEMIFUMARATE  VALSARTAN 300MG 320MG TABLET ORAL',
#  'ESOMEPRAZOLE SODIUM 20MG INJECTABLE INTRAVENOUS',
#  'SODIUM IODIDE I-123 200 CAPSULE ORAL',
#  'SODIUM OXYBATE 500MG SOLUTION ORAL',
#  'OXALIPLATIN 50MG INJECTABLE IV INFUSION',
#  'DEXTROSE 2.5GM 100ML INJECTABLE INJECTION',
#  'LEUPROLIDE ACETATE 7.5MG INJECTABLE INJECTION',
#  'SODIUM IODIDE I-123 100 CAPSULE ORAL',
#  'HALCINONIDE 0.1 0% SOLUTION TOPICAL',
#  'AMPICILLIN SODIUM 2GM INJECTABLE INJECTION',
#  'AMPICILLIN SODIUM 2GM POWDER INTRAVENOUS',
#  'SCOPOLAMINE 1MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'INSULIN ZINC SUSP RECOMBINANT HUMAN 100 INJECTABLE INJECTION',
#  'CISPLATIN 1MG INJECTABLE INJECTION',
#  'PRAZEPAM 5MG CAPSULE ORAL',
#  'AMINOPHYLLINE 105MG 5ML SOLUTION ORAL',
#  'AMOXICILLIN  CLAVULANATE POTASSIUM 1GM 2.5MG TABLET EXTENDED RELEASE ORAL',
#  'DESOXIMETASONE 0.2 5% CREAM TOPICAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 224MG 100ML 225MG 100ML INJECTABLE INJECTION',
#  'GLUCAGON HYDROCHLORIDE 1MG POWDER INTRAMUSCULAR INTRAVENOUS',
#  'PROCAINE HYDROCHLORIDE 2% INJECTABLE INJECTION',
#  'NITROFURAZONE 0.2 0% POWDER TOPICAL',
#  'MEROPENEM 1GM POWDER IV INFUSION',
#  'CLONIDINE HYDROCHLORIDE 0.1MG/ML INJECTABLE INJECTION',
#  'GONADOTROPIN CHORIONIC 00 INJECTABLE INJECTION',
#  'EPIRUBICIN HYDROCHLORIDE 2MG/ML INJECTABLE INJECTION',
#  'VANCOMYCIN HYDROCHLORIDE 1GM INJECTABLE INJECTION',
#  'ACETAMINOPHEN  CODEINE PHOSPHATE 325MG 60MG TABLET ORAL',
#  'VENLAFAXINE HYDROCHLORIDE 7.5MG TABLET ORAL',
#  'MALATHION 0.5 0% LOTION TOPICAL',
#  'TACROLIMUS 0.0 3% OINTMENT TOPICAL',
#  'DOXAPRAM HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 2.5GM 100ML 5.2MG 100ML 567MG 100ML 392MG 100ML SOLUTION INTRAPERITONEAL',
#  'SODIUM BICARBONATE 0.5 INJECTABLE INJECTION',
#  'AZELASTINE HYDROCHLORIDE 0.1876MG SPRAY METERED NASAL',
#  'ERYTHROMYCIN 5MG OINTMENT OPHTHALMIC',
#  'MAGNESIUM SULFATE  POTASSIUM SULFATE  SODIUM SULFATE 1.6GM 3.13GM 7.5GM SOLUTION ORAL',
#  'CYCLOPHOSPHAMIDE 2GM INJECTABLE INJECTION',
#  'FOSAPREPITANT DIMEGLUMINE 150MG POWDER INTRAVENOUS',
#  'DEXAMETHASONE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 0.1 3.5MG 00 SUSPENSION/DROPS OPHTHALMIC',
#  'DACARBAZINE 100MG INJECTABLE INJECTION',
#  'CEFEPIME HYDROCHLORIDE EQ 20MG BASE/ML INJECTABLE INJECTION',
#  'FLUTICASONE PROPIONATE 0.22MG POWDER INHALATION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 1.5GM 100ML 5.2MG 100ML 567MG 100ML 392MG 100ML SOLUTION INTRAPERITONEAL',
#  'MORPHINE SULFATE 10MG/ML INJECTABLE LIPOSOMAL EPIDURAL',
#  'MANNITOL 5GM 100ML INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  GLUTATHIONE DISULFIDE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM PHOSPHATE 0.154MG 0.92MG 0.184MG 0.2MG 0.38MG 2.1MG 7.14MG 0.42MG SOLUTION IRRIGATION',
#  'HYDROCHLOROTHIAZIDE  OLMESARTAN MEDOXOMIL 2.5MG 20MG TABLET ORAL',
#  'NICOTINE POLACRILEX 2MG GUM CHEWING BUCCAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.035MG 1MG TABLET ORAL-28',
#  'CLINDAMYCIN PHOSPHATE 18MG INJECTABLE INJECTION',
#  'HYDROXYZINE HYDROCHLORIDE 25MG INJECTABLE INJECTION',
#  'DEXMEDETOMIDINE HYDROCHLORIDE EQ 100MCG BASE/ML SOLUTION IV INFUSION',
#  'AMPICILLIN/AMPICILLIN TRIHYDRATE 125MG 5ML FOR SUSPENSION ORAL',
#  'VANCOMYCIN HYDROCHLORIDE 250MG 5ML FOR SOLUTION ORAL',
#  'DEXAMETHASONE SODIUM PHOSPHATE 20MG INJECTABLE INJECTION',
#  'GENTAMICIN SULFATE 2MG INJECTABLE INJECTION',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.005MG 0.5 INJECTABLE INJECTION',
#  'ALMOTRIPTAN MALATE 2.5MG TABLET ORAL',
#  'PRAZEPAM 10MG TABLET ORAL',
#  'OXYTOCIN 10USP UNITS/ML INJECTABLE INJECTION',
#  'LEVETIRACETAM 1GM TABLET ORAL',
#  'CARBIDOPA  ENTACAPONE  LEVODOPA 8.75MG 200MG 75MG TABLET ORAL',
#  'CEFTRIAXONE SODIUM  LIDOCAINE 500MG 1% INJECTABLE INJECTION',
#  'PROGESTERONE 50MG INJECTABLE INJECTION',
#  'METHYLPREDNISOLONE SODIUM SUCCINATE 125MG INJECTABLE INJECTION',
#  'GUANETHIDINE MONOSULFATE 25MG TABLET ORAL',
#  'LOPINAVIR  RITONAVIR 80MG 20MG SOLUTION ORAL',
#  "ALPHA-TOCOPHEROL ACETATE  ASCORBIC ACID  BIOTIN  CHOLECALCIFEROL  CYANOCOBALAMIN  DEXPANTHENOL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE HYDROCHLORIDE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE HYDROCHLORIDE  VITAMIN A PALMITATE  VITAMIN K 40MG 3MG 120 8MG 1.2MG 0.72MG 1.2MG 660 0.03MG INJECTABLE IV INFUSION",
#  'FLUTICASONE PROPIONATE 0.0 5% CREAM TOPICAL',
#  'FONDAPARINUX SODIUM 7.5MG 0.6ML INJECTABLE SUBCUTANEOUS',
#  'PRILOCAINE HYDROCHLORIDE 4% INJECTABLE INJECTION',
#  'MEPROBAMATE 600MG TABLET ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 4.25GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'LEVODOPA 250MG CAPSULE ORAL',
#  'DOXORUBICIN HYDROCHLORIDE 2MG INJECTABLE INJECTION',
#  'KETOROLAC TROMETHAMINE 15MG INJECTABLE INJECTION',
#  'FENTANYL CITRATE 0.1MG TABLET BUCCAL SUBLINGUAL',
#  'CLOBETASOL PROPIONATE 0.0 5% OINTMENT TOPICAL',
#  'NISOLDIPINE 5.5MG TABLET EXTENDED RELEASE ORAL',
#  'GENTAMICIN SULFATE 0.8MG INJECTABLE INJECTION',
#  'PANTOPRAZOLE SODIUM 40MG POWDER IV INFUSION',
#  'CHOLESTYRAMINE 4GM BAR CHEWABLE ORAL',
#  'CEFAZOLIN SODIUM 1GM INJECTABLE INJECTION',
#  'RESERPINE 0.5MG TABLET ORAL',
#  'EPINEPHRINE BITARTRATE  ETIDOCAINE HYDROCHLORIDE 0.005MG 1.5 INJECTABLE INJECTION',
#  'RESERPINE 1MG TABLET ORAL',
#  'INDOCYANINE GREEN 25MG INJECTABLE INJECTION',
#  'MAGNESIUM SULFATE 500MG/ML SOLUTION INTRAMUSCULAR INTRAVENOUS',
#  'AMIODARONE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE 420GM 1.48GM 5.72GM 1.2GM FOR SOLUTION ORAL',
#  'ETHINYL ESTRADIOL  NORETHINDRONE 0.05MG 1MG TABLET ORAL-28',
#  'DOPAMINE HYDROCHLORIDE 160MG 100ML INJECTABLE INJECTION',
#  'FOSPHENYTOIN SODIUM 50MG INJECTABLE INJECTION',
#  'CLADRIBINE 1MG INJECTABLE INJECTION',
#  'LEVOTHYROXINE SODIUM 0.137MG 1.8 TABLET ORAL',
#  'DEXTROSE 500MG INJECTABLE INJECTION',
#  'IDOXURIDINE 0.1 0% SOLUTION/DROPS OPHTHALMIC',
#  'CLAVULANATE POTASSIUM  TICARCILLIN DISODIUM 100MG 3GM INJECTABLE INJECTION',
#  'ESTROGENS CONJUGATED  MEDROXYPROGESTERONE ACETATE 0.625MG 0.625MG 5MG TABLET ORAL-28',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE 75MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'CALCIUM GLUCEPTATE 90MG 5ML INJECTABLE INJECTION',
#  'IOHEXOL 5.5 0% SOLUTION INJECTION ORAL',
#  'AMPHETAMINE RESIN COMPLEX  DEXTROAMPHETAMINE RESIN COMPLEX 3.75MG 3.75MG CAPSULE EXTENDED RELEASE ORAL',
#  'CLINDAMYCIN PHOSPHATE 1% AEROSOL FOAM TOPICAL',
#  'PROTIRELIN 0.5MG INJECTABLE INJECTION',
#  'AMINOCAPROIC ACID 1.25GM 5ML SYRUP ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.3MG 100ML 3.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'CYTARABINE 500MG INJECTABLE INJECTION',
#  'PREDNISOLONE TEBUTATE 20MG INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M SESTAMIBI KIT nan INJECTABLE INJECTION',
#  'DIETHYLSTILBESTROL 0.5MG TABLET DELAYED RELEASE ORAL',
#  'AMINO ACIDS 5.2GM/100ML INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 6MG INJECTABLE INJECTION',
#  'ASPIRIN  PRAVASTATIN SODIUM 81MG 40MG TABLET TABLET TABLET ORAL',
#  'ACYCLOVIR SODIUM 1GM INJECTABLE INJECTION',
#  'DESOGESTREL  ETHINYL ESTRADIOL 0.15MG 0.03MG TABLET ORAL-28',
#  'DIGOXIN 0.1MG INJECTABLE INJECTION',
#  'DESOGESTREL  ETHINYL ESTRADIOL 0.15MG 0.03MG TABLET ORAL-21',
#  'LAMIVUDINE 10MG SOLUTION ORAL',
#  'CEFADROXIL/CEFADROXIL HEMIHYDRATE 1GM TABLET ORAL',
#  'FLORBETAPIR F-18 13.5-51mCi/ML SOLUTION INTRAVENOUS',
#  'NITROGLYCERIN 20MG 100ML INJECTABLE INJECTION',
#  'BUTABARBITAL SODIUM 2.4MG TABLET ORAL',
#  'FLUTICASONE PROPIONATE 0.044MG POWDER INHALATION',
#  'MEMANTINE HYDROCHLORIDE 2MG SOLUTION ORAL',
#  'OCTREOTIDE ACETATE 0.1MG INJECTABLE INJECTION',
#  'DIPHENHYDRAMINE HYDROCHLORIDE 2.5MG 5ML SYRUP ORAL',
#  'LEVONORGESTREL 36MG IMPLANT IMPLANTATION',
#  'OXACILLIN SODIUM 4GM INJECTABLE INJECTION',
#  'LACTULOSE 10GM 15ML SOLUTION ORAL RECTAL',
#  'NITROFURAZONE 0.2 0% OINTMENT TOPICAL',
#  'BETAMETHASONE DIPROPIONATE 0.0 5% SPRAY TOPICAL',
#  'MILRINONE LACTATE EQ 0.2MG BASE/ML INJECTABLE INJECTION',
#  'ISOETHARINE HYDROCHLORIDE 0.2 0% SOLUTION INHALATION',
#  'ISOETHARINE HYDROCHLORIDE 0.1 0% SOLUTION INHALATION',
#  'ISOETHARINE HYDROCHLORIDE 0.0 8% SOLUTION INHALATION',
#  'LIDOCAINE HYDROCHLORIDE 0.5 0% INJECTABLE INJECTION',
#  'PENICILLIN G POTASSIUM 400 000 5ML FOR SOLUTION ORAL',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 330MG 100ML INJECTABLE INJECTION',
#  'PROMETHAZINE HYDROCHLORIDE 25MG 5ML SYRUP ORAL',
#  'OMEPRAZOLE MAGNESIUM 20MG TABLET DELAYED RELEASE ORAL',
#  'BUPIVACAINE HYDROCHLORIDE  EPINEPHRINE 0.5 0.005MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 20MG 100ML 5GM 100ML 105MG 100ML 600MG 100ML 310MG 100ML INJECTABLE INJECTION',
#  'ETHCHLORVYNOL 750MG CAPSULE ORAL',
#  'PROMETHAZINE HYDROCHLORIDE 25MG INJECTABLE INJECTION',
#  'HYDROMORPHONE HYDROCHLORIDE 4MG INJECTABLE INJECTION',
#  'TESTOSTERONE 40.5MG/2.5GM PACKET GEL TRANSDERMAL',
#  'PEMOLINE 7.5MG TABLET ORAL',
#  'OMEPRAZOLE  SODIUM BICARBONATE 40MG 1.68GM FOR SUSPENSION ORAL',
#  'AMINO ACIDS  MAGNESIUM ACETATE  POTASSIUM ACETATE  SODIUM CHLORIDE 3.5 21MG 100ML 128MG 100ML 234MG 100ML INJECTABLE INJECTION',
#  'TRIMEPRAZINE TARTRATE 2.5MG 5ML SYRUP ORAL',
#  'LEUPROLIDE ACETATE 1MG 0.2ML INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 224MG 100ML 300MG 100ML INJECTABLE INJECTION',
#  'METHOTREXATE SODIUM EQ 25MG BASE/ML INJECTABLE INJECTION',
#  'NEOMYCIN SULFATE  TRIAMCINOLONE ACETONIDE 3.5MG 0.1 OINTMENT TOPICAL',
#  'AZLOCILLIN SODIUM 2GM INJECTABLE INJECTION',
#  'KETAMINE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE 1MEQ/ML INJECTABLE INJECTION',
#  'BACITRACIN ZINC  POLYMYXIN B SULFATE 500 00 OINTMENT OPHTHALMIC',
#  'SOMATROPIN RECOMBINANT 5MG 1.5ML INJECTABLE INJECTION',
#  'DEXAMETHASONE SODIUM PHOSPHATE 24MG INJECTABLE INJECTION',
#  'MESTRANOL  NORETHINDRONE 0.05MG 1MG TABLET ORAL-21',
#  'FLUOCINOLONE ACETONIDE 0.0 1% SHAMPOO TOPICAL',
#  'AMINO ACIDS  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 5.5 102MG 100ML 522MG 100ML 431MG 100ML 224MG 100ML INJECTABLE INJECTION',
#  'DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM GLUCONATE 5GM 100ML 30MG 100ML 37MG 100ML 370MG 100ML 530MG 100ML 500MG 100ML INJECTABLE INJECTION',
#  'MESTRANOL  NORETHINDRONE 0.05MG 1MG TABLET ORAL-28',
#  'CEFAZOLIN SODIUM 250MG INJECTABLE INJECTION',
#  'HYDROCORTISONE VALERATE 0.2 0% CREAM TOPICAL',
#  'ENOXAPARIN SODIUM 100MG/ML INJECTABLE INTRAVENOUS SUBCUTANEOUS',
#  'IPRATROPIUM BROMIDE 0.021MG SPRAY METERED NASAL',
#  'FLUDEOXYGLUCOSE F-18 0-2 INJECTABLE INTRAVENOUS',
#  'PREDNISOLONE SODIUM PHOSPHATE 30MG TABLET ORALLY DISINTEGRATING ORAL',
#  'NAFCILLIN SODIUM 1GM INJECTABLE INJECTION',
#  'BECLOMETHASONE DIPROPIONATE 0.08MG AEROSOL METERED NASAL',
#  'TETRACYCLINE PHOSPHATE COMPLEX 500MG CAPSULE ORAL',
#  'CHLORDIAZEPOXIDE  ESTROGENS ESTERIFIED 5MG 0.2MG TABLET ORAL',
#  'DEXAMETHASONE SODIUM PHOSPHATE 0.1MG AEROSOL NASAL',
#  'OFLOXACIN 0.3 0% SOLUTION/DROPS OPHTHALMIC',
#  'CHLOROTHIAZIDE SODIUM 500MG INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 2MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 2.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'FAMOTIDINE 40MG TABLET ORALLY DISINTEGRATING ORAL',
#  'NICOTINE 14MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'INSULIN RECOMBINANT PURIFIED HUMAN 100 INJECTABLE INJECTION',
#  'THIORIDAZINE HYDROCHLORIDE 30MG CONCENTRATE ORAL',
#  'DEXMEDETOMIDINE HYDROCHLORIDE EQ 4MCG BASE/ML INJECTABLE INJECTION',
#  'MENADIOL SODIUM DIPHOSPHATE 10MG INJECTABLE INJECTION',
#  'CEFTAZIDIME 500MG INJECTABLE INJECTION',
#  'MEZLOCILLIN SODIUM MONOHYDRATE 3GM INJECTABLE INJECTION',
#  'CEFUROXIME SODIUM 1.5GM INJECTABLE INJECTION',
#  'NITROFURAZONE 0.2 0% DRESSING TOPICAL',
#  'HYDROCORTISONE ACETATE  NEOMYCIN SULFATE 1% 3.5MG OINTMENT TOPICAL',
#  'TRIPTORELIN PAMOATE 2.5MG INJECTABLE INTRAMUSCULAR',
#  'CEPHALOTHIN SODIUM 2GM INJECTABLE INJECTION',
#  'FLUPHENAZINE HYDROCHLORIDE 5MG CONCENTRATE ORAL',
#  'ZIDOVUDINE 10MG INJECTABLE INJECTION',
#  'DROPERIDOL  FENTANYL CITRATE 2.5MG 0.05MG INJECTABLE INJECTION',
#  'CHOLINE C-11 4-3 3.1 INJECTABLE INTRAVENOUS',
#  'ALPROSTADIL 0.01MG INJECTABLE INJECTION',
#  'CARBOPLATIN 450MG INJECTABLE INJECTION',
#  'DESMOPRESSIN ACETATE 0.15MG SPRAY METERED NASAL',
#  'MESTRANOL  NORETHINDRONE 0.08MG 1MG TABLET ORAL-21',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 4.25GM 100ML 15MG 100ML 560MG 100ML 390MG 100ML SOLUTION INTRAPERITONEAL',
#  'METRONIDAZOLE 0.7 5% CREAM TOPICAL',
#  'PAMIDRONATE DISODIUM 90MG INJECTABLE INJECTION',
#  'LEVONORGESTREL 75MG IMPLANT IMPLANTATION',
#  'CALCIUM CHLORIDE  DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 20MG 100ML 5GM 100ML 254MG 100ML 600MG 100ML 310MG 100ML INJECTABLE INJECTION',
#  'METHYLPREDNISOLONE SODIUM SUCCINATE 40MG INJECTABLE INJECTION',
#  'ACETAMINOPHEN  ASPIRIN  CODEINE PHOSPHATE 150MG 180MG 60MG CAPSULE ORAL',
#  'HYDROCHLOROTHIAZIDE  TELMISARTAN 2.5MG 80MG TABLET ORAL',
#  'LEVETIRACETAM 1GM TABLET EXTENDED RELEASE ORAL',
#  'DEXTROSE  SODIUM CHLORIDE 5GM 100ML 110MG 100ML INJECTABLE INJECTION',
#  'LEVOTHYROXINE SODIUM 0.075MG 1.8 TABLET ORAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE 29MG 100ML 2.5GM 100ML 15MG 100ML 610MG 100ML 560MG 100ML SOLUTION INTRAPERITONEAL',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.01MG 2% SOLUTION IONTOPHORESIS',
#  'INAMRINONE LACTATE 5MG INJECTABLE INJECTION',
#  'TRETINOIN 0.0 5% CREAM TOPICAL',
#  'MANNITOL 15GM 100ML INJECTABLE INJECTION',
#  'SOYBEAN OIL 30% INJECTABLE INJECTION',
#  'ALISKIREN HEMIFUMARATE  AMLODIPINE BESYLATE  HYDROCHLOROTHIAZIDE 300MG 5MG 2.5MG TABLET ORAL',
#  'CLINDAMYCIN PHOSPHATE 12MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 220MG 100ML 200MG 100ML INJECTABLE INJECTION',
#  'BLEOMYCIN SULFATE EQ 30 UNITS BASE/VIAL INJECTABLE INJECTION',
#  'AZELASTINE HYDROCHLORIDE 0.125MG SPRAY METERED NASAL',
#  'CEFOPERAZONE SODIUM 2GM INJECTABLE INJECTION',
#  'CLINDAMYCIN PHOSPHATE  TRETINOIN 1.2 0.0 25% GEL TOPICAL',
#  'STERILE WATER FOR IRRIGATION 100% LIQUID IRRIGATION',
#  'VINORELBINE TARTRATE 10MG INJECTABLE INJECTION',
#  'SODIUM CHLORIDE 3GM 100ML INJECTABLE INJECTION',
#  'PIPERACILLIN SODIUM 4GM INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.3MG 100ML 1.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'FONDAPARINUX SODIUM 5MG 0.4ML INJECTABLE SUBCUTANEOUS',
#  'PAROXETINE HYDROCHLORIDE 7.5MG TABLET EXTENDED RELEASE ORAL',
#  'AMINOCAPROIC ACID 250MG INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM ACETATE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 4.2 5% 10GM 100ML 51MG 100ML 176 5MG 100ML 2.4MG 100ML 104 5MG 100ML 205MG 100ML INJECTABLE INJECTION',
#  'TERBUTALINE SULFATE 1MG INJECTABLE INJECTION',
#  'CEFUROXIME SODIUM 7.5GM INJECTABLE INJECTION',
#  'NICOTINE 21MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CALCIUM CHLORIDE  DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 20MG 100ML 5GM 100ML 30MG 100ML 600MG 100ML 310MG 100ML INJECTABLE INJECTION',
#  'AMMONIA N-13 3.7 5-2 INJECTABLE INTRAVENOUS',
#  'AMINO ACIDS 4GM/100ML INJECTABLE INJECTION',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 5MG 5MG 5MG 5MG CAPSULE ORAL',
#  'FENTANYL 2.5 FILM EXTENDED RELEASE TRANSDERMAL',
#  'TRETINOIN 0.0 4% GEL TOPICAL',
#  'BENZTHIAZIDE 50MG TABLET ORAL',
#  'TERCONAZOLE 0.8 0% CREAM VAGINAL',
#  'BUSULFAN 6MG INJECTABLE INJECTION',
#  'AMINO ACIDS  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 8.5 102MG 100ML 45MG 100ML 522MG 100ML 410MG 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 4.2 5% 10GM 100ML 51MG 100ML 261MG 100ML 297MG 100ML 77MG 100ML INJECTABLE INJECTION',
#  'IOPAMIDOL 41% INJECTABLE INJECTION',
#  'MEGESTROL ACETATE 40MG SUSPENSION ORAL',
#  'TECHNETIUM TC-99M GLUCEPTATE KIT nan INJECTABLE INJECTION',
#  'IBUPROFEN 40MG SUSPENSION/DROPS ORAL',
#  'CLOBETASOL PROPIONATE 0.0 5% AEROSOL FOAM TOPICAL',
#  'CYCLOPHOSPHAMIDE 200MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 1.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'RAUWOLFIA SERPENTINA ROOT 100MG TABLET ORAL',
#  'CORTICOTROPIN 25 UNITS/VIAL INJECTABLE INJECTION',
#  'CLONIDINE HYDROCHLORIDE 0.5MG/ML INJECTABLE INJECTION',
#  'ETHCHLORVYNOL 200MG CAPSULE ORAL',
#  'OXTRIPHYLLINE 100MG 5ML SOLUTION ORAL',
#  'CYCLOTHIAZIDE 2MG TABLET ORAL',
#  'CHOLESTYRAMINE 4GM POWDER ORAL',
#  'DIETHYLSTILBESTROL 1MG TABLET DELAYED RELEASE ORAL',
#  'LEUCOVORIN CALCIUM 100MG INJECTABLE INJECTION',
#  'PROMAZINE HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM PHOSPHATE 5000ML INJECTABLE INJECTION',
#  'TRETINOIN 0.0 1% GEL TOPICAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 298MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'INSULIN LISPRO PROTAMINE RECOMBINANT  INSULIN LISPRO RECOMBINANT 50 UNITS/ML 50 UNITS/ML INJECTABLE INJECTION',
#  'FISH OIL  MEDIUM CHAIN TRIGLYCERIDES  OLIVE OIL  SOYBEAN OIL 500ML EMULSION INTRAVENOUS',
#  'CHLORAMPHENICOL 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM SULFATE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM GLYCEROPHOSPHATE  SOYBEAN OIL 1920ML EMULSION IV INFUSION',
#  'CIPROFLOXACIN 400MG 200ML INJECTABLE INJECTION',
#  'KANAMYCIN SULFATE 500MG 2ML INJECTABLE INJECTION',
#  'DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM GLUCONATE 5GM 100ML 30MG 100ML 37MG 100ML 368MG 100ML 526MG 100ML 502MG 100ML INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE 510MG 100ML 50GM 100ML 200MG 100ML 9.2GM 100ML 9.6GM 100ML SOLUTION INTRAPERITONEAL',
#  'DOCETAXEL 40MG/ML INJECTABLE INJECTION',
#  'CHLORPHENIRAMINE MALEATE 12MG CAPSULE EXTENDED RELEASE ORAL',
#  'CYCLOSPORINE 50MG INJECTABLE INJECTION',
#  'CEFUROXIME SODIUM 750MG INJECTABLE INTRAMUSCULAR INTRAVENOUS',
#  'PIPERACILLIN SODIUM 2GM INJECTABLE INJECTION',
#  'ETOMIDATE 2MG INJECTABLE INJECTION',
#  'EXENATIDE SYNTHETIC 2MG FOR SUSPENSION EXTENDED RELEASE SUBCUTANEOUS',
#  'HYDROCORTISONE 2.5 0% OINTMENT TOPICAL',
#  'AMINO ACIDS  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 3.5 51MG 100ML 131MG 100ML 218MG 100ML 35MG 100ML INJECTABLE INJECTION',
#  'BUPIVACAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 0.5 0.0091MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.4MG 100ML 1.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'CIDOFOVIR 75MG INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE 2.98GM 100ML INJECTABLE INJECTION',
#  'BEPRIDIL HYDROCHLORIDE 400MG TABLET ORAL',
#  'AMINO ACIDS  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM CHLORIDE  SODIUM PHOSPHATE DIBASIC HEPTAHYDRATE 4.2 5% 10GM 100ML 30MG 100ML 97MG 100ML 120MG 100ML 9.3MG 100ML INJECTABLE INJECTION',
#  'ALUMINUM HYDROXIDE  MAGNESIUM TRISILICATE 80MG 20MG TABLET CHEWABLE ORAL',
#  'PREDNISOLONE ACETATE 50MG INJECTABLE INJECTION',
#  'TOBRAMYCIN SULFATE 10MG INJECTABLE INJECTION',
#  'HYALURONIDASE 150 INJECTABLE INJECTION',
#  'ADENOSINE 3MG INJECTABLE INJECTION',
#  'LORATADINE 1MG SYRUP ORAL',
#  'PIPERAZINE CITRATE 500MG 5ML SYRUP ORAL',
#  'DESLORATADINE  PSEUDOEPHEDRINE SULFATE 5MG 240MG TABLET EXTENDED RELEASE ORAL',
#  'AMOXICILLIN  CLAVULANATE POTASSIUM 400MG 5ML 57MG 5ML FOR SUSPENSION ORAL',
#  'DECITABINE 50MG INJECTABLE INTRAVENOUS',
#  'ENOXAPARIN SODIUM 100MG/ML INJECTABLE SUBCUTANEOUS',
#  'CALCIUM CHLORIDE  DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 20MG 100ML 5GM 100ML 104MG 100ML 600MG 100ML 310MG 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE 5% 25GM 100ML INJECTABLE INJECTION',
#  'CODEINE PHOSPHATE  PSEUDOEPHEDRINE HYDROCHLORIDE  TRIPROLIDINE HYDROCHLORIDE 10MG 5ML 30MG 5ML 1.25MG 5ML SYRUP ORAL',
#  'POTASSIUM CHLORIDE 4MEQ/ML INJECTABLE INJECTION',
#  'AMINO ACIDS  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 7% 102MG 100ML 45MG 100ML 522MG 100ML 410MG 100ML INJECTABLE INJECTION',
#  'GADOFOSVESET TRISODIUM 244MG/ML SOLUTION INTRAVENOUS',
#  'CEPHRADINE 125MG 5ML FOR SUSPENSION ORAL',
#  'FENTANYL CITRATE 0.4MG TABLET BUCCAL SUBLINGUAL',
#  'CALCIPOTRIENE 0.0 1% OINTMENT TOPICAL',
#  'HYDROCORTISONE 2.5 0% LOTION TOPICAL',
#  'CALCITONIN SALMON 200 INJECTABLE INJECTION',
#  'DAUNORUBICIN HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'BACITRACIN  HYDROCORTISONE ACETATE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 400 1% 3.5MG 00 OINTMENT OPHTHALMIC',
#  'CHLOROPROCAINE HYDROCHLORIDE 2% INJECTABLE INJECTION',
#  'FOLLITROPIN ALFA/BETA 75 IU/VIAL INJECTABLE SUBCUTANEOUS',
#  'CEPHRADINE 250MG 5ML FOR SUSPENSION ORAL',
#  'GENTAMICIN SULFATE 40MG 100ML INJECTABLE INJECTION',
#  'EPTIFIBATIDE 2MG INJECTABLE INJECTION',
#  'ESOMEPRAZOLE MAGNESIUM 20MG FOR SUSPENSION DELAYED RELEASE ORAL',
#  'METHYLTESTOSTERONE 10MG TABLET BUCCAL SUBLINGUAL',
#  'CEPHALOTHIN SODIUM 40MG INJECTABLE INJECTION',
#  'DOBUTAMINE HYDROCHLORIDE 50MG 100ML INJECTABLE INJECTION',
#  'MAGNESIUM SULFATE 1GM 100ML INJECTABLE INJECTION',
#  'OXACILLIN SODIUM 10GM INJECTABLE INJECTION',
#  'CARBOPLATIN 10MG/ML INJECTABLE IV INFUSION',
#  'THEOPHYLLINE 250MG CAPSULE ORAL',
#  'MENOTROPINS FSH LH 75 IU/VIAL 75 IU/VIAL INJECTABLE INJECTION',
#  'LOTEPREDNOL ETABONATE 0.5 0% SUSPENSION/DROPS OPHTHALMIC',
#  'METAPROTERENOL SULFATE 0.4 0% SOLUTION INHALATION',
#  'BETAMETHASONE DIPROPIONATE  CALCIPOTRIENE HYDRATE 0.0 64% 0.0 05% SUSPENSION TOPICAL',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 26MG 100ML 1.5GM 100ML 5MG 100ML 530MG 100ML 450MG 100ML SOLUTION INTRAPERITONEAL',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.005MG 2% INJECTABLE INJECTION',
#  'DEXAMETHASONE SODIUM PHOSPHATE 4MG INJECTABLE INJECTION',
#  'VANCOMYCIN HYDROCHLORIDE 5GM INJECTABLE INJECTION',
#  'HEPARIN SODIUM 200 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE 3.5 5GM 100ML INJECTABLE INJECTION',
#  'BETAMETHASONE BENZOATE 0.0 3% OINTMENT TOPICAL',
#  'MITOMYCIN 20MG INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M SODIUM PERTECHNETATE GENERATOR 0.2 5-3 SOLUTION INTRAVENOUS',
#  'NOREPINEPHRINE BITARTRATE 1MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 149MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'EDROPHONIUM CHLORIDE 10MG INJECTABLE INJECTION',
#  'CALCITONIN SALMON 200 SPRAY METERED NASAL',
#  'METHOCARBAMOL 100MG/ML SOLUTION IM-IV',
#  'PENICILLIN G PROCAINE 600 000 INJECTABLE INJECTION',
#  'CEFAZOLIN SODIUM 10MG INJECTABLE INJECTION',
#  'CYTARABINE 20MG INJECTABLE INJECTION',
#  'NAPROXEN SODIUM  PSEUDOEPHEDRINE HYDROCHLORIDE 220MG 120MG TABLET EXTENDED RELEASE ORAL',
#  'ALCLOMETASONE DIPROPIONATE 0.0 5% OINTMENT TOPICAL',
#  'PREDNISOLONE 2.5MG TABLET ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 224MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'BENZTHIAZIDE 25MG TABLET ORAL',
#  'DIPHENHYDRAMINE HYDROCHLORIDE 2.5MG 5ML ELIXIR ORAL',
#  'INSULIN SUSP PROTAMINE ZINC BEEF/PORK 40 UNITS/ML INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  TRIAMTERENE 25MG 7.5MG TABLET ORAL',
#  'THIORIDAZINE HYDROCHLORIDE 100MG CONCENTRATE ORAL',
#  'POLYMYXIN B SULFATE 100 000 000 POWDER FOR RX COMPOUNDING',
#  'PIPERACILLIN SODIUM  TAZOBACTAM SODIUM 4GM 500MG INJECTABLE INJECTION',
#  'HYDROCORTISONE  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 1% 3.5MG 00 SOLUTION/DROPS OTIC',
#  'POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM BICARBONATE  SODIUM CHLORIDE  SODIUM SULFATE ANHYDROUS 227 1GM 2.82GM 6.36GM 5.53GM 1.5GM FOR SOLUTION ORAL',
#  'PROMETHAZINE HYDROCHLORIDE 2.5MG SUPPOSITORY RECTAL',
#  'ASPIRIN  PROPOXYPHENE NAPSYLATE 325MG 100MG TABLET ORAL',
#  'ADAPALENE 0.1 0% SOLUTION TOPICAL',
#  'AMINO ACIDS  DEXTROSE 2.7 5% 5GM 100ML INJECTABLE INJECTION',
#  'NAPROXEN SODIUM 250MG TABLET ORAL',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 3.75MG 3.75MG 3.75MG 3.75MG TABLET ORAL',
#  'MEZLOCILLIN SODIUM MONOHYDRATE 4GM INJECTABLE INJECTION',
#  'SUGAMMADEX SODIUM EQ 100MG BASE/ML SOLUTION INTRAVENOUS',
#  'AMINO ACIDS  DEXTROSE 3.5 25GM 100ML INJECTABLE INJECTION',
#  'BETAMETHASONE DIPROPIONATE  CLOTRIMAZOLE 0.0 5% 1% CREAM TOPICAL',
#  'OXTRIPHYLLINE 100MG TABLET DELAYED RELEASE ORAL',
#  'FOSINOPRIL SODIUM  HYDROCHLOROTHIAZIDE 10MG 2.5MG TABLET ORAL',
#  'FLURANDRENOLIDE 0.0 5% LOTION TOPICAL',
#  'LEVOTHYROXINE SODIUM 0.05MG 1.8 TABLET ORAL',
#  'CHLORPROMAZINE HYDROCHLORIDE 100MG CONCENTRATE ORAL',
#  'BUDESONIDE 0.032MG SPRAY METERED NASAL',
#  'LORAZEPAM 2MG CONCENTRATE ORAL',
#  'CEPHAPIRIN SODIUM 4GM INJECTABLE INJECTION',
#  'ALPROSTADIL 0.02MG INJECTABLE INJECTION',
#  'CEPHALEXIN 100MG FOR SUSPENSION ORAL',
#  'STAVUDINE 1MG FOR SOLUTION ORAL',
#  'ESOMEPRAZOLE MAGNESIUM 40MG CAPSULE DELAYED REL PELLETS ORAL',
#  'AZLOCILLIN SODIUM 4GM INJECTABLE INJECTION',
#  'ATROPINE 2MG 0.7ML INJECTABLE INJECTION',
#  'GADOXETATE DISODIUM 181.43MG/ML SOLUTION INTRAVENOUS',
#  'MOMETASONE FUROATE 0.05MG SPRAY METERED NASAL',
#  'PREDNISOLONE SODIUM PHOSPHATE 10MG TABLET ORALLY DISINTEGRATING ORAL',
#  'DOCETAXEL 10MG/ML INJECTABLE INJECTION',
#  'SODIUM FLUORIDE F-18 0-2 INJECTABLE INTRAVENOUS',
#  'ISOPROTERENOL HYDROCHLORIDE 0.5 0% SOLUTION INHALATION',
#  'METHOTREXATE SODIUM 100MG INJECTABLE INJECTION',
#  'GENTAMICIN SULFATE 1.2MG INJECTABLE INJECTION',
#  'NYSTATIN 500 000 TABLET ORAL',
#  'PROCAINE HYDROCHLORIDE  TETRACYCLINE HYDROCHLORIDE 40MG 250MG INJECTABLE INJECTION',
#  'AZLOCILLIN SODIUM 3GM INJECTABLE INJECTION',
#  'CEFUROXIME SODIUM 1.5GM INJECTABLE INTRAMUSCULAR INTRAVENOUS',
#  'BUPIVACAINE HYDROCHLORIDE 0.2 5% INJECTABLE INJECTION',
#  'PROCAINE HYDROCHLORIDE  TETRACYCLINE HYDROCHLORIDE 40MG 100MG INJECTABLE INJECTION',
#  'METHOTREXATE SODIUM 20MG INJECTABLE INJECTION',
#  'POLYETHYLENE GLYCOL 3350 17GM FOR SOLUTION ORAL',
#  'ESTRONE 5MG INJECTABLE INJECTION',
#  'EMPAGLIFLOZIN  METFORMIN HYDROCHLORIDE 2.5MG 1GM TABLET ORAL',
#  'ERYTHROMYCIN LACTOBIONATE 1GM INJECTABLE INJECTION',
#  'AMPICILLIN SODIUM 125MG INJECTABLE INJECTION',
#  'ACETAMINOPHEN  HYDROCODONE BITARTRATE 500MG 15ML 5MG 15ML SOLUTION ORAL',
#  'OCTREOTIDE ACETATE 0.5MG INJECTABLE INJECTION',
#  'CEPHALOTHIN SODIUM 20MG INJECTABLE INJECTION',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE 120MG CAPSULE EXTENDED RELEASE ORAL',
#  'ISOSULFAN BLUE 1% INJECTABLE INJECTION',
#  'LABETALOL HYDROCHLORIDE 5MG INJECTABLE INJECTION',
#  'BETAMETHASONE DIPROPIONATE 0.0 5% OINTMENT AUGMENTED TOPICAL',
#  'POTASSIUM CHLORIDE 9.8MG INJECTABLE INJECTION',
#  'ALBUTEROL SULFATE 0.0 21% SOLUTION INHALATION',
#  'PENICILLIN G POTASSIUM 50 00 INJECTABLE INJECTION',
#  'HYDROCORTISONE ACETATE 50MG INJECTABLE INJECTION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 3.5 6.8MG 100ML 25GM 100ML 51MG 100ML 2.4MG 100ML 261MG 100ML 205MG 100ML INJECTABLE INJECTION',
#  'AMPHETAMINE ADIPATE  AMPHETAMINE SULFATE  DEXTROAMPHETAMINE ADIPATE  DEXTROAMPHETAMINE SULFATE 5MG 5MG 5MG 5MG TABLET ORAL',
#  'THEOPHYLLINE 150MG 15ML SYRUP ORAL',
#  'ERYTHROMYCIN ETHYLSUCCINATE 200MG TABLET CHEWABLE ORAL',
#  'LEVOTHYROXINE SODIUM 0.1MG 1.8 TABLET ORAL',
#  'ERGOLOID MESYLATES 0.5MG TABLET SUBLINGUAL',
#  'BUPIVACAINE HYDROCHLORIDE 0.7 5% INJECTABLE SPINAL',
#  'PHENYTOIN SODIUM 50MG INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  RESERPINE 50MG 0.1MG TABLET ORAL',
#  'CEFOTAXIME SODIUM 20MG INJECTABLE INJECTION',
#  'CICLOPIROX 0.7 7% GEL TOPICAL',
#  'POTASSIUM ACETATE 2MEQ/ML INJECTABLE INJECTION',
#  'LIDOCAINE HYDROCHLORIDE 400MG 100ML INJECTABLE INJECTION',
#  'HYDRALAZINE HYDROCHLORIDE 20MG INJECTABLE INJECTION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM CHLORIDE 4.2 5% 6.8MG 100ML 20GM 100ML 51MG 100ML 2.4MG 100ML 261MG 100ML 205MG 100ML INJECTABLE INJECTION',
#  'AMINO ACIDS  DEXTROSE 4.2 5% 10GM 100ML INJECTABLE INJECTION',
#  'TETRACYCLINE PHOSPHATE COMPLEX 250MG CAPSULE ORAL',
#  'THIAMINE HYDROCHLORIDE 100MG INJECTABLE INJECTION',
#  'CEFTRIAXONE SODIUM 500MG INJECTABLE INJECTION',
#  'NAPROXEN SODIUM  PSEUDOEPHEDRINE HYDROCHLORIDE 200MG 120MG TABLET EXTENDED RELEASE ORAL',
#  'HALCINONIDE 0.0 3% OINTMENT TOPICAL',
#  'HYDROMORPHONE HYDROCHLORIDE 10MG INJECTABLE INJECTION',
#  'RIFAMPIN 600MG INJECTABLE INJECTION',
#  'GENTAMICIN SULFATE 2MG INJECTABLE INTRATHECAL',
#  'HYDROCORTISONE SODIUM SUCCINATE 500MG INJECTABLE INJECTION',
#  'EPINEPHRINE EQ 1MG BASE/ML SOLUTION IV INFUSION INTRAOCULAR INTRAMUSCULAR SUBCUTANEOUS',
#  'MESTRANOL  NORETHINDRONE 0.08MG 1MG TABLET ORAL-28',
#  'PALONOSETRON HYDROCHLORIDE EQ 0.05MG BASE/ML SOLUTION INTRAVENOUS',
#  'PENICILLIN G POTASSIUM 10 00 INJECTABLE INJECTION',
#  'BRETYLIUM TOSYLATE 400MG 100ML INJECTABLE INJECTION',
#  'HEXACHLOROPHENE 0.2 5% SOLUTION TOPICAL',
#  'TAZAROTENE 0.1 0% CREAM TOPICAL',
#  'POTASSIUM CHLORIDE 3MEQ/ML INJECTABLE INJECTION',
#  'EPINEPHRINE 0.2MG AEROSOL METERED INHALATION',
#  'ACITRETIN 2.5MG CAPSULE ORAL',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 298MG 100ML 300MG 100ML INJECTABLE INJECTION',
#  'CHLORPHENIRAMINE MALEATE 100MG INJECTABLE INJECTION',
#  'HYDROXOCOBALAMIN 5GM/KIT INJECTABLE INJECTION',
#  'SUMATRIPTAN SUCCINATE EQ 8MG BASE/ML INJECTABLE SUBCUTANEOUS',
#  'CILASTATIN SODIUM  IMIPENEM 500MG 500MG POWDER INTRAVENOUS',
#  'CARPHENAZINE MALEATE 50MG TABLET ORAL',
#  'METHYLPREDNISOLONE ACETATE 40MG INJECTABLE INJECTION',
#  'AMMONIUM CHLORIDE 5MEQ/ML INJECTABLE INJECTION',
#  'VINCRISTINE SULFATE 1MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 5.7MG 100ML 4.25GM 100ML 5.2MG 100ML 567MG 100ML 392MG 100ML SOLUTION INTRAPERITONEAL',
#  'PROCHLORPERAZINE EDISYLATE 10MG CONCENTRATE ORAL',
#  'VITAMIN A PALMITATE 00 CAPSULE ORAL',
#  'KANAMYCIN SULFATE 75MG 2ML INJECTABLE INJECTION',
#  'DOCETAXEL 20MG/ML INJECTABLE INJECTION',
#  'SODIUM CHLORIDE 900MG 100ML INJECTABLE INJECTION',
#  'SUCCINYLCHOLINE CHLORIDE 100MG INJECTABLE INJECTION',
#  'CHROMIC CHLORIDE 0.004MG INJECTABLE INJECTION',
#  'MELPHALAN HYDROCHLORIDE 50MG INJECTABLE INJECTION',
#  'DEXAMETHASONE ACETATE 8MG INJECTABLE INJECTION',
#  'IOPROMIDE 6.9 0% INJECTABLE INJECTION',
#  'POLYMYXIN B SULFATE 500 000 INJECTABLE INJECTION',
#  'IRON DEXTRAN 50MG INJECTABLE INJECTION',
#  'NITROGLYCERIN 0.8MG INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.4MG 100ML 3.5GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'DOPAMINE HYDROCHLORIDE 160MG INJECTABLE INJECTION',
#  'MITOXANTRONE HYDROCHLORIDE EQ 2MG BASE/ML INJECTABLE INJECTION',
#  'THIOTHIXENE HYDROCHLORIDE 5MG CONCENTRATE ORAL',
#  "ASCORBIC ACID  BIOTIN  CYANOCOBALAMIN  DEXPANTHENOL  ERGOCALCIFEROL  FOLIC ACID  NIACINAMIDE  PYRIDOXINE HYDROCHLORIDE  RIBOFLAVIN 5'-PHOSPHATE SODIUM  THIAMINE HYDROCHLORIDE  VITAMIN A  VITAMIN E  VITAMIN K 200MG 0.06MG 0.005MG 15MG 0.005MG 0.6MG 40MG 6MG 3.6MG 6MG 1MG 10MG 0.15MG INJECTABLE IV INFUSION",
#  'TRISULFAPYRIMIDINES SULFADIAZINE SULFAMERAZINE SULFAMETHAZINE 167MG 167MG 167MG TABLET ORAL',
#  'SODIUM CHLORIDE 9MG INJECTABLE INJECTION',
#  'CARBENICILLIN DISODIUM 5GM INJECTABLE INJECTION',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE 29MG 100ML 4.25GM 100ML 15MG 100ML 610MG 100ML 560MG 100ML SOLUTION INTRAPERITONEAL',
#  'PENTAMIDINE ISETHIONATE 300MG INJECTABLE INJECTION',
#  'ALENDRONATE SODIUM  CHOLECALCIFEROL 70MG 56 TABLET ORAL',
#  'FLUNISOLIDE 0.029MG SPRAY METERED NASAL',
#  'PANCURONIUM BROMIDE 2MG INJECTABLE INJECTION',
#  'CLOZAPINE 200MG TABLET ORALLY DISINTEGRATING ORAL',
#  'CISATRACURIUM BESYLATE 10MG INJECTABLE INJECTION',
#  'DOBUTAMINE HYDROCHLORIDE 2.5MG INJECTABLE INJECTION',
#  'METFORMIN HYDROCHLORIDE  ROSIGLITAZONE MALEATE 1GM 4MG TABLET ORAL',
#  'BUPIVACAINE HYDROCHLORIDE 0.5 0% INJECTABLE INJECTION',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.01MG 1% INJECTABLE INJECTION',
#  'TIROFIBAN HYDROCHLORIDE EQ 0.25MG BASE/ML SOLUTION INJECTION',
#  'GENTAMICIN SULFATE 80MG 100ML INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  VALSARTAN 2.5MG 320MG TABLET ORAL',
#  'CLOBETASOL PROPIONATE 0.0 5% SOLUTION TOPICAL',
#  'ISOETHARINE HYDROCHLORIDE 0.1 7% SOLUTION INHALATION',
#  'AMOXICILLIN 50MG FOR SUSPENSION ORAL',
#  'TRETINOIN 0.0 5% GEL TOPICAL',
#  'BACITRACIN ZINC  NEOMYCIN SULFATE  POLYMYXIN B SULFATE 400 3.5MG 50 OINTMENT TOPICAL',
#  'TECHNETIUM TC-99M MEBROFENIN KIT nan INJECTABLE INJECTION',
#  'BETAMETHASONE DIPROPIONATE 0.0 5% CREAM TOPICAL',
#  'STRONTIUM CHLORIDE SR-89 1mCi/ML INJECTABLE INJECTION',
#  'PREDNISOLONE SODIUM PHOSPHATE 0.1 1% SOLUTION/DROPS OPHTHALMIC',
#  'TRIAMCINOLONE ACETONIDE 10MG INJECTABLE INJECTION',
#  'BETAXOLOL HYDROCHLORIDE  CHLORTHALIDONE 5MG 2.5MG TABLET ORAL',
#  'CALCIPOTRIENE 0.0 1% CREAM TOPICAL',
#  'GADODIAMIDE 287MG/ML INJECTABLE INJECTION',
#  'MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  POTASSIUM PHOSPHATE MONOBASIC  SODIUM ACETATE  SODIUM CHLORIDE  SODIUM GLUCONATE  SODIUM PHOSPHATE DIBASIC HEPTAHYDRATE 30MG 100ML 37MG 100ML 0.82MG 100ML 370MG 100ML 530MG 100ML 500MG 100ML 12MG 100ML INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M RED BLOOD CELL KIT nan INJECTABLE INJECTION',
#  'IFOSFAMIDE 3GM INJECTABLE INJECTION',
#  'NALOXONE HYDROCHLORIDE 1MG INJECTABLE INJECTION',
#  'DIENESTROL 0.0 1% CREAM VAGINAL',
#  'FOSINOPRIL SODIUM  HYDROCHLOROTHIAZIDE 20MG 2.5MG TABLET ORAL',
#  'FLURANDRENOLIDE  NEOMYCIN SULFATE 0.0 5% 3.5MG OINTMENT TOPICAL',
#  'OXTRIPHYLLINE 50MG 5ML SYRUP ORAL',
#  'AMPHETAMINE RESIN COMPLEX  DEXTROAMPHETAMINE RESIN COMPLEX 6.25MG 6.25MG CAPSULE EXTENDED RELEASE ORAL',
#  'CYCLACILLIN 250MG TABLET ORAL',
#  'CHLORHEXIDINE GLUCONATE  ISOPROPYL ALCOHOL 10.5ML SPONGE TOPICAL',
#  'INDOMETHACIN SODIUM 1MG INJECTABLE INJECTION',
#  'MESTRANOL  NORETHYNODREL 0.075MG 5MG TABLET ORAL-20',
#  'PEMOLINE 8.75MG TABLET ORAL',
#  'GENTAMICIN SULFATE 70MG 100ML INJECTABLE INJECTION',
#  'BUTABARBITAL SODIUM 30MG 5ML ELIXIR ORAL',
#  'HYDROCHLOROTHIAZIDE  VALSARTAN 2.5MG 80MG TABLET ORAL',
#  'PENICILLIN G POTASSIUM 250 000 TABLET ORAL',
#  'OMEPRAZOLE  SODIUM BICARBONATE 20MG 1.68GM FOR SUSPENSION ORAL',
#  'IRON SUCROSE EQ 20MG BASE/ML INJECTABLE INTRAVENOUS',
#  'IPRATROPIUM BROMIDE 0.042MG SPRAY METERED NASAL',
#  'AMINO ACIDS 7GM/100ML INJECTABLE INJECTION',
#  'TRIAMCINOLONE DIACETATE 40MG INJECTABLE INJECTION',
#  'POTASSIUM CHLORIDE  SODIUM CHLORIDE 150MG 100ML 900MG 100ML INJECTABLE INJECTION',
#  'DICLOFENAC SODIUM 1.5 0% SOLUTION TOPICAL',
#  'ERGOLOID MESYLATES 1MG SOLUTION ORAL',
#  'HEPARIN SODIUM 50 0.5ML INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  LABETALOL HYDROCHLORIDE 25MG 100MG TABLET ORAL',
#  'AMINO ACIDS 8GM/100ML INJECTABLE INJECTION',
#  'GALANTAMINE HYDROBROMIDE 4MG SOLUTION ORAL',
#  'MEPIVACAINE HYDROCHLORIDE 1% INJECTABLE INJECTION',
#  'BECLOMETHASONE DIPROPIONATE 0.04MG AEROSOL METERED NASAL',
#  'DEXTROSE  POTASSIUM CHLORIDE 5GM 100ML 150MG 100ML INJECTABLE INJECTION',
#  'CEFOTETAN DISODIUM 10GM INJECTABLE INJECTION',
#  'FISH OIL  MEDIUM CHAIN TRIGLYCERIDES  OLIVE OIL  SOYBEAN OIL 250ML EMULSION INTRAVENOUS',
#  'NITROFURAZONE 0.2 0% SOLUTION TOPICAL',
#  'ROPIVACAINE HYDROCHLORIDE 2MG/ML SOLUTION INJECTION',
#  'LEUPROLIDE ACETATE 2.5MG INJECTABLE SUBCUTANEOUS',
#  'HYDROXYPROGESTERONE CAPROATE 125MG INJECTABLE INJECTION',
#  'SOMATROPIN RECOMBINANT 5MG INJECTABLE INJECTION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 5% 33MG 100ML 25GM 100ML 51MG 100ML 261MG 100ML 340MG 100ML 59MG 100ML INJECTABLE INJECTION',
#  'CHYMOTRYPSIN 750 FOR SOLUTION OPHTHALMIC',
#  'METOCLOPRAMIDE HYDROCHLORIDE 10MG TABLET ORALLY DISINTEGRATING ORAL',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 5% 33MG 100ML 35GM 100ML 51MG 100ML 261MG 100ML 340MG 100ML 59MG 100ML INJECTABLE INJECTION',
#  'EPINEPHRINE  LIDOCAINE HYDROCHLORIDE 0.005MG 1.5 INJECTABLE INJECTION',
#  'CALCITRIOL 0.001MG INJECTABLE INJECTION',
#  'PSEUDOEPHEDRINE HYDROCHLORIDE  TRIPROLIDINE HYDROCHLORIDE 120MG 5MG CAPSULE EXTENDED RELEASE ORAL',
#  'DOPAMINE HYDROCHLORIDE 80MG INJECTABLE INJECTION',
#  'ERYTHROMYCIN LACTOBIONATE 500MG INJECTABLE INJECTION',
#  'CEFTRIAXONE SODIUM 250MG INJECTABLE INJECTION',
#  'DESOGESTREL  ETHINYL ESTRADIOL 0.1MG 0.125MG 0.15MG 0.025MG 0.025MG 0.025MG TABLET ORAL-28',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 149MG 100ML 300MG 100ML INJECTABLE INJECTION',
#  'CHLORTHALIDONE  METOPROLOL TARTRATE 25MG 200MG CAPSULE ORAL',
#  'LINAGLIPTIN  METFORMIN HYDROCHLORIDE 2.5MG 1GM TABLET ORAL',
#  'GADOPENTETATE DIMEGLUMINE 469 01MG INJECTABLE INJECTION',
#  'ASCORBIC ACID  POLYETHYLENE GLYCOL 3350  POTASSIUM CHLORIDE  SODIUM ASCORBATE  SODIUM CHLORIDE  SODIUM SULFATE 4.7GM 100GM 1.015GM 5.9GM 2.691GM 7.5GM FOR SOLUTION ORAL',
#  'TRETINOIN 0.0 3% CREAM TOPICAL',
#  'AMINO ACIDS 5GM/100ML INJECTABLE INJECTION',
#  'TRIAMCINOLONE ACETONIDE 0.0 3% LOTION TOPICAL',
#  'HYDROCHLOROTHIAZIDE  MOEXIPRIL HYDROCHLORIDE 2.5MG 15MG TABLET ORAL',
#  'GATIFLOXACIN 0.5 0% SOLUTION/DROPS OPHTHALMIC',
#  'OXYBUTYNIN 3.9MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CEFOTETAN DISODIUM 1GM INJECTABLE INJECTION',
#  'HYDROCHLOROTHIAZIDE  VALSARTAN 2.5MG 160MG TABLET ORAL',
#  'DOXYCYCLINE HYCLATE 80MG TABLET DELAYED RELEASE ORAL',
#  'MICONAZOLE NITRATE 2% 200MG CREAM SUPPOSITORY TOPICAL VAGINAL',
#  'DESONIDE 0.0 5% LOTION TOPICAL',
#  'FLUTICASONE FUROATE  VILANTEROL TRIFENATATE 0.2MG 0.025MG POWDER INHALATION',
#  'BUPIVACAINE HYDROCHLORIDE  EPINEPHRINE BITARTRATE 0.7 5% 0.0091MG INJECTABLE INJECTION',
#  'ETHINYL ESTRADIOL  NORGESTIMATE 0.035MG 0.035MG 0.035MG 0.18MG 0.215MG 0.25MG TABLET ORAL-28',
#  'LEVOTHYROXINE SODIUM 500 POWDER INTRAVENOUS',
#  'XENON XE-133 10mCi/VIAL GAS INHALATION',
#  'CEFAMANDOLE NAFATE 2GM INJECTABLE INJECTION',
#  'DEXTROSE 10GM 100ML INJECTABLE INJECTION',
#  'MESALAMINE 1GM SUPPOSITORY RECTAL',
#  'PHENTERMINE HYDROCHLORIDE 7.5MG TABLET ORALLY DISINTEGRATING ORAL',
#  'SODIUM PHENYLBUTYRATE 3GM POWDER ORAL',
#  'TESTOSTERONE 4MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CLOTRIMAZOLE 1% 100MG CREAM TABLET TOPICAL VAGINAL',
#  'DIFLORASONE DIACETATE 0.0 5% CREAM TOPICAL',
#  'CLONIDINE 0.1MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CEFAZOLIN SODIUM 20GM INJECTABLE INJECTION',
#  'MORPHINE SULFATE 2MG INJECTABLE INJECTION',
#  'FLURANDRENOLIDE 0.0 5% OINTMENT TOPICAL',
#  'RIBAVIRIN 6GM FOR SOLUTION INHALATION',
#  'METOCLOPRAMIDE HYDROCHLORIDE 5MG INJECTABLE INJECTION',
#  'CILASTATIN SODIUM  IMIPENEM 250MG 250MG POWDER INTRAVENOUS',
#  'CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  SODIUM CHLORIDE  SODIUM LACTATE 8.3MG 100ML 4.25GM 100ML 5.08MG 100ML 538MG 100ML 448MG 100ML SOLUTION INTRAPERITONEAL',
#  'GUAIFENESIN 1.2GM TABLET EXTENDED RELEASE ORAL',
#  'CYCLOPHOSPHAMIDE 100MG INJECTABLE INJECTION',
#  'IPODATE SODIUM 500MG CAPSULE ORAL',
#  'SOYBEAN OIL 20% INJECTABLE INJECTION',
#  'TRETINOIN 0.0 8% GEL TOPICAL',
#  'PENICILLIN G PROCAINE 300 000 INJECTABLE INJECTION',
#  'TECHNETIUM TC-99M PYROPHOSPHATE KIT nan INJECTABLE INJECTION',
#  'MEZLOCILLIN SODIUM MONOHYDRATE 2GM INJECTABLE INJECTION',
#  'DIETHYLSTILBESTROL 0.5MG SUPPOSITORY VAGINAL',
#  'GENTAMICIN SULFATE 3MG SOLUTION/DROPS OPHTHALMIC',
#  'TECHNETIUM TC-99M MEDRONATE KIT nan INJECTABLE INJECTION',
#  'DEFEROXAMINE MESYLATE 2GM INJECTABLE INJECTION',
#  'RANOLAZINE 1GM TABLET EXTENDED RELEASE ORAL',
#  'CORTICOTROPIN 40 UNITS/VIAL INJECTABLE INJECTION',
#  'AMOXICILLIN  CLARITHROMYCIN  LANSOPRAZOLE 500MG 500MG 30MG CAPSULE CAPSULE DELAYED REL PELLETS TABLET ORAL',
#  'NITROGLYCERIN 0.2MG FILM EXTENDED RELEASE TRANSDERMAL',
#  'CEFTRIAXONE SODIUM 20MG INJECTABLE INJECTION',
#  'TIMOLOL MALEATE 0.5 SOLUTION GEL FORMING/DROPS OPHTHALMIC',
#  'DEXCHLORPHENIRAMINE MALEATE 2MG 5ML SYRUP ORAL',
#  'CHLORPHENIRAMINE MALEATE  PSEUDOEPHEDRINE HYDROCHLORIDE 12MG 120MG CAPSULE EXTENDED RELEASE ORAL',
#  'TESTOSTERONE 20.25MG/1.25GM PACKET GEL TRANSDERMAL',
#  'CHLORHEXIDINE GLUCONATE 0.5 0% SOLUTION TOPICAL',
#  'INSULIN SUSP ISOPHANE SEMISYNTHETIC PURIFIED HUMAN 100 INJECTABLE INJECTION',
#  'AMINO ACIDS  CALCIUM CHLORIDE  DEXTROSE  MAGNESIUM CHLORIDE  POTASSIUM PHOSPHATE DIBASIC  SODIUM ACETATE  SODIUM CHLORIDE 2.7 5% 33MG 100ML 25GM 100ML 51MG 100ML 261MG 100ML 217MG 100ML 112MG 100ML INJECTABLE INJECTION',
#  'KETOPROFEN 2.5MG TABLET ORAL',
#  'ADENOSINE 3MG/ML SOLUTION IV INFUSION',
#  'MEROPENEM 1GM INJECTABLE INJECTION',
#  'GLUTETHIMIDE 250MG TABLET ORAL',
#  'CALCIUM CHLORIDE  MAGNESIUM CHLORIDE  POTASSIUM CHLORIDE  SODIUM ACETATE  SODIUM CHLORIDE 6.5MG 5.4MG 4.6MG 121MG 6.1MG INJECTABLE INJECTION',
#  'ESTRADIOL CYPIONATE 5MG INJECTABLE INJECTION',
#  'DEXTROSE  POTASSIUM CHLORIDE  SODIUM CHLORIDE 5GM 100ML 150MG 100ML 330MG 100ML INJECTABLE INJECTION',
#  ...}

# %%
1-float(sum(missingRxCUI))/len(RxCUI_levels_file.index)
# Out:
# 0.6174685418208734

# %%
# Out:
# 33775
